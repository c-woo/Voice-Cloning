# %%
import os

from trainer import Trainer, TrainerArgs

from TTS.config.shared_configs import BaseAudioConfig
from TTS.tts.configs.glow_tts_config import GlowTTSConfig
from TTS.tts.configs.shared_configs import BaseDatasetConfig
from TTS.tts.datasets import load_tts_samples
from TTS.tts.models.glow_tts import GlowTTS
from TTS.tts.utils.speakers import SpeakerManager
from TTS.tts.utils.text.tokenizer import TTSTokenizer
from TTS.utils.audio import AudioProcessor
# Out:
# C:\Users\Chris\Anaconda3\envs\torch\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')

# %%
dataset_path = 'D:\data\TIMIT\TRAIN'
output_path = 'D:\data\TIMIT'

# %%
# define dataset config
# need to use vctk_old format if using wav files instead of flac

dataset_config = BaseDatasetConfig(name="vctk_old", meta_file_train="", language='en-us', path=dataset_path)

# %%
# define audio config

audio_config = BaseAudioConfig(sample_rate=22050,
                               preemphasis=0.98,
                               power=1.2,
                               ref_level_db=2,
                               resample=True, 
                               do_trim_silence=False, 
                               trim_db=23.0)

# %%
# define model config

config = GlowTTSConfig(
    batch_size=64,
    eval_batch_size=16,
    num_loader_workers=0,
    num_eval_loader_workers=0,
    precompute_num_workers=0,
    run_eval=True,
    test_delay_epochs=-1,
    epochs=1000,
    text_cleaner="phoneme_cleaners",
    use_phonemes=True,
    phoneme_language="en-us",
    phoneme_cache_path=os.path.join(output_path, "phoneme_cache"),
    print_step=25,
    print_eval=False,
    mixed_precision=True,
    output_path=output_path,
    datasets=[dataset_config],
    use_speaker_embedding=True,
    min_text_len=0,
    max_text_len=500,
    min_audio_len=0,
    max_audio_len=500000,
)

# %%
# INITIALIZE THE AUDIO PROCESSOR
# Audio processor is used for feature extraction and audio I/O.
# It mainly serves to the dataloader and the training loggers.
ap = AudioProcessor.init_from_config(audio_config)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:True
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:2
#  | > fft_size:1024
#  | > power:1.2
#  | > preemphasis:0.98
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:23.0
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024

# %%
# INITIALIZE THE TOKENIZER
# Tokenizer is used to convert text to sequences of token IDs.
# If characters are not defined in the config, default characters are passed to the config
tokenizer, config = TTSTokenizer.init_from_config(config)

# %%
# LOAD DATA SAMPLES
# Each sample is a list of ```[text, audio_file_path, speaker_name]```

train_samples, eval_samples = load_tts_samples(
    dataset_config,
    eval_split=True,
    eval_split_max_size=config.eval_split_max_size,
    eval_split_size=config.eval_split_size,
)
# Out:
#  | > Found 140 files in D:\data\TIMIT\TRAIN

# %%
# init speaker manager for multi-speaker training

speaker_manager = SpeakerManager()
speaker_manager.set_ids_from_data(train_samples + eval_samples, parse_key="speaker_name")
config.num_speakers = speaker_manager.num_speakers

# %%
# init model
model = GlowTTS(config, ap, tokenizer, speaker_manager=speaker_manager)
# Out:
#  > Init speaker_embedding layer.

# %%
# INITIALIZE THE TRAINER

trainer = Trainer(
    TrainerArgs(), config, output_path, model=model, train_samples=train_samples, eval_samples=eval_samples
)
# Out:
#  > Using CUDA: True
#  > Number of GPUs: 1
#
#  > Model has 32336209 parameters
#  > `speakers.pth` is saved to D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\speakers.pth.
#  > `speakers_file` is updated in the config.json.

# %%
trainer.fit()
# Out:
#  > EPOCH: 0/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:29:15)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 0/3 -- GLOBAL_STEP: 0
#      | > current_lr: 0.00000
#      | > step_time: 1.56420  (1.56416)
#      | > loader_time: 0.47860  (0.47858)
#
# C:\Users\Chris\Anaconda3\envs\torch\lib\site-packages\torch\optim\lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
# ðə tu ɑɹtɪsts ɪkst͡ʃeɪnd͡ʒd ɔtoʊɡɹæfs.
#  [!] Character '͡' not found in the vocabulary. Discarding it.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.37734 (+0.00000)
#      | > avg_loss: 2.82171 (+0.00000)
#      | > avg_log_mle: 0.65565 (+0.00000)
#      | > avg_loss_dur: 2.16606 (+0.00000)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_3.pth
#
#  > EPOCH: 1/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:29:26)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01501 (-0.36233)
#      | > avg_loss: 2.82171 (+0.00000)
#      | > avg_log_mle: 0.65565 (+0.00000)
#      | > avg_loss_dur: 2.16606 (+0.00000)
#
#
#  > EPOCH: 2/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:29:31)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01101 (-0.00400)
#      | > avg_loss: 2.82171 (+0.00000)
#      | > avg_log_mle: 0.65565 (+0.00000)
#      | > avg_loss_dur: 2.16606 (+0.00000)
#
#
#  > EPOCH: 3/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:29:37)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00200)
#      | > avg_loss: 2.81372 (-0.00798)
#      | > avg_log_mle: 0.65264 (-0.00301)
#      | > avg_loss_dur: 2.16108 (-0.00497)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_12.pth
#
#  > EPOCH: 4/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:29:44)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00100)
#      | > avg_loss: 2.81358 (-0.00014)
#      | > avg_log_mle: 0.65264 (-0.00000)
#      | > avg_loss_dur: 2.16095 (-0.00014)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_15.pth
#
#  > EPOCH: 5/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:29:54)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (-0.00000)
#      | > avg_loss: 2.81339 (-0.00019)
#      | > avg_log_mle: 0.65263 (-0.00001)
#      | > avg_loss_dur: 2.16076 (-0.00018)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_18.pth
#
#  > EPOCH: 6/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:02)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00100)
#      | > avg_loss: 2.81297 (-0.00042)
#      | > avg_log_mle: 0.65259 (-0.00003)
#      | > avg_loss_dur: 2.16038 (-0.00039)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_21.pth
#
#  > EPOCH: 7/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:10)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00100)
#      | > avg_loss: 2.81229 (-0.00068)
#      | > avg_log_mle: 0.65254 (-0.00006)
#      | > avg_loss_dur: 2.15975 (-0.00062)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_24.pth
#
#  > EPOCH: 8/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:20)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 1/3 -- GLOBAL_STEP: 25
#      | > loss: 2.29974  (2.29974)
#      | > log_mle: 0.58258  (0.58258)
#      | > loss_dur: 1.71715  (1.71715)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 8.25363  (8.25363)
#      | > current_lr: 0.00000
#      | > step_time: 1.08940  (1.08937)
#      | > loader_time: 0.42340  (0.42338)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00000)
#      | > avg_loss: 2.81135 (-0.00094)
#      | > avg_log_mle: 0.65246 (-0.00008)
#      | > avg_loss_dur: 2.15889 (-0.00087)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_27.pth
#
#  > EPOCH: 9/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:28)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00100)
#      | > avg_loss: 2.81013 (-0.00122)
#      | > avg_log_mle: 0.65236 (-0.00010)
#      | > avg_loss_dur: 2.15777 (-0.00112)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_30.pth
#
#  > EPOCH: 10/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:37)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01101 (+0.00200)
#      | > avg_loss: 2.80862 (-0.00151)
#      | > avg_log_mle: 0.65223 (-0.00013)
#      | > avg_loss_dur: 2.15639 (-0.00138)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_33.pth
#
#  > EPOCH: 11/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:45)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00200)
#      | > avg_loss: 2.80678 (-0.00184)
#      | > avg_log_mle: 0.65208 (-0.00015)
#      | > avg_loss_dur: 2.15470 (-0.00169)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_36.pth
#
#  > EPOCH: 12/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:30:55)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.80461 (-0.00217)
#      | > avg_log_mle: 0.65190 (-0.00018)
#      | > avg_loss_dur: 2.15271 (-0.00199)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_39.pth
#
#  > EPOCH: 13/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:03)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00100)
#      | > avg_loss: 2.80213 (-0.00249)
#      | > avg_log_mle: 0.65170 (-0.00021)
#      | > avg_loss_dur: 2.15043 (-0.00228)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_42.pth
#
#  > EPOCH: 14/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:11)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00100)
#      | > avg_loss: 2.79929 (-0.00284)
#      | > avg_log_mle: 0.65146 (-0.00024)
#      | > avg_loss_dur: 2.14783 (-0.00260)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_45.pth
#
#  > EPOCH: 15/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:19)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00000)
#      | > avg_loss: 2.79611 (-0.00318)
#      | > avg_log_mle: 0.65119 (-0.00027)
#      | > avg_loss_dur: 2.14492 (-0.00291)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_48.pth
#
#  > EPOCH: 16/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:27)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 2/3 -- GLOBAL_STEP: 50
#      | > loss: 2.43811  (2.36504)
#      | > log_mle: 0.57656  (0.57892)
#      | > loss_dur: 1.86154  (1.78612)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 9.17145  (8.68049)
#      | > current_lr: 0.00000
#      | > step_time: 0.40440  (0.72316)
#      | > loader_time: 0.10110  (0.26724)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.79259 (-0.00352)
#      | > avg_log_mle: 0.65090 (-0.00030)
#      | > avg_loss_dur: 2.14170 (-0.00322)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_51.pth
#
#  > EPOCH: 17/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:36)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.78875 (-0.00384)
#      | > avg_log_mle: 0.65057 (-0.00033)
#      | > avg_loss_dur: 2.13818 (-0.00351)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_54.pth
#
#  > EPOCH: 18/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:44)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00000)
#      | > avg_loss: 2.78457 (-0.00418)
#      | > avg_log_mle: 0.65020 (-0.00036)
#      | > avg_loss_dur: 2.13437 (-0.00381)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_57.pth
#
#  > EPOCH: 19/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:31:52)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.78008 (-0.00449)
#      | > avg_log_mle: 0.64980 (-0.00040)
#      | > avg_loss_dur: 2.13027 (-0.00410)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_60.pth
#
#  > EPOCH: 20/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:00)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.77525 (-0.00483)
#      | > avg_log_mle: 0.64937 (-0.00043)
#      | > avg_loss_dur: 2.12588 (-0.00439)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_63.pth
#
#  > EPOCH: 21/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:08)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00100)
#      | > avg_loss: 2.76321 (-0.01204)
#      | > avg_log_mle: 0.64890 (-0.00047)
#      | > avg_loss_dur: 2.11431 (-0.01157)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_66.pth
#
#  > EPOCH: 22/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:17)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (-0.00000)
#      | > avg_loss: 2.75775 (-0.00547)
#      | > avg_log_mle: 0.64839 (-0.00051)
#      | > avg_loss_dur: 2.10936 (-0.00496)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_69.pth
#
#  > EPOCH: 23/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:26)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01101 (+0.00100)
#      | > avg_loss: 2.75199 (-0.00576)
#      | > avg_log_mle: 0.64784 (-0.00055)
#      | > avg_loss_dur: 2.10415 (-0.00521)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_72.pth
#
#  > EPOCH: 24/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:35)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00200)
#      | > avg_loss: 2.74589 (-0.00610)
#      | > avg_log_mle: 0.64725 (-0.00059)
#      | > avg_loss_dur: 2.09865 (-0.00550)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_75.pth
#
#  > EPOCH: 25/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:43)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 0/3 -- GLOBAL_STEP: 75
#      | > loss: 2.18137  (2.18137)
#      | > log_mle: 0.56456  (0.56456)
#      | > loss_dur: 1.61681  (1.61681)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 7.99229  (7.99229)
#      | > current_lr: 0.00001
#      | > step_time: 0.74370  (0.74368)
#      | > loader_time: 0.32430  (0.32429)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00000)
#      | > avg_loss: 2.73930 (-0.00659)
#      | > avg_log_mle: 0.64661 (-0.00064)
#      | > avg_loss_dur: 2.09269 (-0.00595)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_78.pth
#
#  > EPOCH: 26/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:51)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.73222 (-0.00707)
#      | > avg_log_mle: 0.64592 (-0.00069)
#      | > avg_loss_dur: 2.08630 (-0.00639)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_81.pth
#
#  > EPOCH: 27/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:32:59)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.72498 (-0.00724)
#      | > avg_log_mle: 0.64519 (-0.00074)
#      | > avg_loss_dur: 2.07980 (-0.00651)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_84.pth
#
#  > EPOCH: 28/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:33:07)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00000)
#      | > avg_loss: 2.71746 (-0.00752)
#      | > avg_log_mle: 0.64440 (-0.00079)
#      | > avg_loss_dur: 2.07307 (-0.00673)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_87.pth
#
#  > EPOCH: 29/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:33:15)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 2.66508 (-0.05238)
#      | > avg_log_mle: 0.64355 (-0.00085)
#      | > avg_loss_dur: 2.02153 (-0.05154)
#
#  > BEST MODEL : D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436\best_model_90.pth
#
#  > EPOCH: 30/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 04:33:23)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
# ...
#
#
#  > EPOCH: 989/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:57:54)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00100)
#      | > avg_loss: 0.89102 (+0.02915)
#      | > avg_log_mle: -0.07650 (+0.03114)
#      | > avg_loss_dur: 0.96752 (-0.00199)
#
#
#  > EPOCH: 990/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:58:03)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00100)
#      | > avg_loss: 0.86764 (-0.02338)
#      | > avg_log_mle: -0.09385 (-0.01735)
#      | > avg_loss_dur: 0.96149 (-0.00604)
#
#
#  > EPOCH: 991/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:58:13)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 2/3 -- GLOBAL_STEP: 2975
#      | > loss: -0.95114  (-0.71691)
#      | > log_mle: -1.01152  (-0.83384)
#      | > loss_dur: 0.06038  (0.11693)
#      | > amp_scaler: 4096.00000  (4096.00000)
#      | > grad_norm: 238.43488  (125.30862)
#      | > current_lr: 0.00025
#      | > step_time: 0.40140  (0.72066)
#      | > loader_time: 0.10310  (0.25773)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 0.86536 (-0.00228)
#      | > avg_log_mle: -0.02099 (+0.07286)
#      | > avg_loss_dur: 0.88635 (-0.07514)
#
#
#  > EPOCH: 992/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:58:22)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 0.83251 (-0.03285)
#      | > avg_log_mle: -0.11767 (-0.09668)
#      | > avg_loss_dur: 0.95018 (+0.06384)
#
#
#  > EPOCH: 993/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:58:32)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00801 (-0.00100)
#      | > avg_loss: 0.82886 (-0.00365)
#      | > avg_log_mle: -0.12907 (-0.01139)
#      | > avg_loss_dur: 0.95793 (+0.00775)
#
#
#  > EPOCH: 994/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:58:41)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00801 (+0.00000)
#      | > avg_loss: 0.78569 (-0.04318)
#      | > avg_log_mle: -0.08536 (+0.04371)
#      | > avg_loss_dur: 0.87105 (-0.08689)
#
#
#  > EPOCH: 995/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:58:50)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00100)
#      | > avg_loss: 0.95340 (+0.16771)
#      | > avg_log_mle: -0.08684 (-0.00148)
#      | > avg_loss_dur: 1.04024 (+0.16919)
#
#
#  > EPOCH: 996/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:59:00)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss: 0.92910 (-0.02430)
#      | > avg_log_mle: -0.09164 (-0.00480)
#      | > avg_loss_dur: 1.02073 (-0.01950)
#
#
#  > EPOCH: 997/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:59:09)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00801 (-0.00100)
#      | > avg_loss: 0.91590 (-0.01320)
#      | > avg_log_mle: -0.08969 (+0.00195)
#      | > avg_loss_dur: 1.00558 (-0.01515)
#
#
#  > EPOCH: 998/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:59:18)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00200)
#      | > avg_loss: 0.86768 (-0.04822)
#      | > avg_log_mle: -0.10486 (-0.01517)
#      | > avg_loss_dur: 0.97254 (-0.03305)
#
#
#  > EPOCH: 999/1000
#  --> D:\data\TIMIT\run-September-09-2022_04+29AM-75f2436
#
#  > TRAINING (2022-09-09 06:59:28)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 139
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 22
#  | > Avg text length: 49.46762589928058
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 27302.0
#  | > Avg audio length: 67225.14388489208
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 1
#  | > Preprocessing samples
#  | > Max text length: 38
#  | > Min text length: 38
#  | > Avg text length: 38.0
#  |
#  | > Max audio length: 50020.0
#  | > Min audio length: 50020.0
#  | > Avg audio length: 50020.0
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00801 (-0.00200)
#      | > avg_loss: 0.84405 (-0.02363)
#      | > avg_log_mle: -0.08234 (+0.02252)
#      | > avg_loss_dur: 0.92639 (-0.04615)
