# %%
import os

from trainer import Trainer, TrainerArgs

from TTS.config.shared_configs import BaseAudioConfig
from TTS.tts.configs.glow_tts_config import GlowTTSConfig
from TTS.tts.configs.shared_configs import BaseDatasetConfig
from TTS.tts.datasets import load_tts_samples
from TTS.tts.models.glow_tts import GlowTTS
from TTS.tts.utils.speakers import SpeakerManager
from TTS.tts.utils.text.tokenizer import TTSTokenizer
from TTS.utils.audio import AudioProcessor
# Out:
# C:\Users\Chris\Anaconda3\envs\torch\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')

# %%
dataset_path = 'D:\data\TIMIT\TRAIN'
output_path = './output'

# %%
# define dataset config
# need to use vctk_old format if using wav files instead of flac

dataset_config = BaseDatasetConfig(name="vctk_old", meta_file_train="", language='en-us', path=dataset_path)

# %%
# define audio config

audio_config = BaseAudioConfig(sample_rate=22050,
                               preemphasis=0.98,
                               power=1.2,
                               ref_level_db=2,
                               resample=True, 
                               do_trim_silence=False, 
                               trim_db=23.0)

# %%
# define model config

config = GlowTTSConfig(
    batch_size=64,
    eval_batch_size=16,
    num_loader_workers=0,
    num_eval_loader_workers=0,
    precompute_num_workers=0,
    run_eval=True,
    test_delay_epochs=-1,
    epochs=1000,
    text_cleaner="phoneme_cleaners",
    use_phonemes=True,
    phoneme_language="en-us",
    phoneme_cache_path=os.path.join(output_path, "phoneme_cache"),
    print_step=25,
    print_eval=False,
    mixed_precision=True,
    output_path=output_path,
    datasets=[dataset_config],
    use_speaker_embedding=True,
    min_text_len=0,
    max_text_len=500,
    min_audio_len=0,
    max_audio_len=500000,
)

# %%
# INITIALIZE THE AUDIO PROCESSOR
# Audio processor is used for feature extraction and audio I/O.
# It mainly serves to the dataloader and the training loggers.
ap = AudioProcessor.init_from_config(audio_config)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:True
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:2
#  | > fft_size:1024
#  | > power:1.2
#  | > preemphasis:0.98
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:0.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:23.0
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024

# %%
# INITIALIZE THE TOKENIZER
# Tokenizer is used to convert text to sequences of token IDs.
# If characters are not defined in the config, default characters are passed to the config
tokenizer, config = TTSTokenizer.init_from_config(config)

# %%
# LOAD DATA SAMPLES
# Each sample is a list of ```[text, audio_file_path, speaker_name]```

train_samples, eval_samples = load_tts_samples(
    dataset_config,
    eval_split=True,
    eval_split_max_size=config.eval_split_max_size,
    eval_split_size=config.eval_split_size,
)
# Out:
#  | > Found 380 files in D:\data\TIMIT\TRAIN

# %%
# init speaker manager for multi-speaker training

speaker_manager = SpeakerManager()
speaker_manager.set_ids_from_data(train_samples + eval_samples, parse_key="speaker_name")
config.num_speakers = speaker_manager.num_speakers

# %%
# init model
model = GlowTTS(config, ap, tokenizer, speaker_manager=speaker_manager)
# Out:
#  > Init speaker_embedding layer.

# %%
# INITIALIZE THE TRAINER

trainer = Trainer(
    TrainerArgs(), config, output_path, model=model, train_samples=train_samples, eval_samples=eval_samples
)
# Out:
#  > Using CUDA: True
#  > Number of GPUs: 1
#
#  > Model has 32340817 parameters
#  > `speakers.pth` is saved to ./output\run-September-12-2022_01+31AM-3a2b985\speakers.pth.
#  > `speakers_file` is updated in the config.json.

# %%
trainer.fit()
# Out:
#  > EPOCH: 0/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
# [*] Pre-computing phonemes...
#   4%|▎         | 14/377 [00:02<00:47,  7.71it/s]
# wɛn pilɪŋ ən ɔɹɪnd͡ʒ, ɪt ɪz hɑɹd nɑt tə spɹeɪ d͡ʒus.
#  [!] Character '͡' not found in the vocabulary. Discarding it.
# 100%|██████████| 377/377 [00:31<00:00, 12.16it/s]
#
#  > TRAINING (2022-09-12 01:32:42)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 0/6 -- GLOBAL_STEP: 0
#      | > current_lr: 0.00000
#      | > step_time: 1.69050  (1.69053)
#      | > loader_time: 0.54320  (0.54318)
#
# C:\Users\Chris\Anaconda3\envs\torch\lib\site-packages\torch\optim\lr_scheduler.py:129: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.32363 (+0.00000)
#      | > avg_loss: 3.71091 (+0.00000)
#      | > avg_log_mle: 0.55406 (+0.00000)
#      | > avg_loss_dur: 3.15685 (+0.00000)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_6.pth
#
#  > EPOCH: 1/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:32:56)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.03403 (-0.28960)
#      | > avg_loss: 3.70885 (-0.00206)
#      | > avg_log_mle: 0.55594 (+0.00188)
#      | > avg_loss_dur: 3.15291 (-0.00394)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_12.pth
#
#  > EPOCH: 2/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:33:07)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02602 (-0.00801)
#      | > avg_loss: 3.70867 (-0.00019)
#      | > avg_log_mle: 0.55594 (-0.00000)
#      | > avg_loss_dur: 3.15273 (-0.00018)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_18.pth
#
#  > EPOCH: 3/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:33:21)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02002 (-0.00600)
#      | > avg_loss: 3.70786 (-0.00081)
#      | > avg_log_mle: 0.55591 (-0.00003)
#      | > avg_loss_dur: 3.15195 (-0.00078)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_24.pth
#
#  > EPOCH: 4/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:33:33)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 1/6 -- GLOBAL_STEP: 25
#      | > loss: 3.28523  (3.28523)
#      | > log_mle: 0.54506  (0.54506)
#      | > loss_dur: 2.74017  (2.74017)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 9.53697  (9.53697)
#      | > current_lr: 0.00000
#      | > step_time: 0.61960  (0.61956)
#      | > loader_time: 0.32530  (0.32529)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (+0.00100)
#      | > avg_loss: 3.70623 (-0.00163)
#      | > avg_log_mle: 0.55585 (-0.00006)
#      | > avg_loss_dur: 3.15038 (-0.00157)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_30.pth
#
#  > EPOCH: 5/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:33:45)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02302 (+0.00200)
#      | > avg_loss: 3.70366 (-0.00257)
#      | > avg_log_mle: 0.55575 (-0.00010)
#      | > avg_loss_dur: 3.14791 (-0.00247)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_36.pth
#
#  > EPOCH: 6/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:33:57)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (-0.00100)
#      | > avg_loss: 3.70044 (-0.00322)
#      | > avg_log_mle: 0.55561 (-0.00014)
#      | > avg_loss_dur: 3.14484 (-0.00307)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_42.pth
#
#  > EPOCH: 7/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:34:09)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (-0.00000)
#      | > avg_loss: 3.69245 (-0.00799)
#      | > avg_log_mle: 0.55542 (-0.00018)
#      | > avg_loss_dur: 3.13703 (-0.00781)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_48.pth
#
#  > EPOCH: 8/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:34:22)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 2/6 -- GLOBAL_STEP: 50
#      | > loss: 3.43325  (3.34740)
#      | > log_mle: 0.55999  (0.55224)
#      | > loss_dur: 2.87326  (2.79516)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 9.66633  (9.59241)
#      | > current_lr: 0.00000
#      | > step_time: 0.68660  (0.66289)
#      | > loader_time: 0.35670  (0.33900)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00100)
#      | > avg_loss: 3.68150 (-0.01095)
#      | > avg_log_mle: 0.55519 (-0.00023)
#      | > avg_loss_dur: 3.12631 (-0.01072)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_54.pth
#
#  > EPOCH: 9/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:34:34)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (+0.00000)
#      | > avg_loss: 3.69297 (+0.01146)
#      | > avg_log_mle: 0.55491 (-0.00028)
#      | > avg_loss_dur: 3.13806 (+0.01174)
#
#
#  > EPOCH: 10/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:34:45)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00000)
#      | > avg_loss: 3.67419 (-0.01877)
#      | > avg_log_mle: 0.55457 (-0.00034)
#      | > avg_loss_dur: 3.11962 (-0.01844)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_66.pth
#
#  > EPOCH: 11/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:34:57)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00000)
#      | > avg_loss: 3.66506 (-0.00914)
#      | > avg_log_mle: 0.55418 (-0.00039)
#      | > avg_loss_dur: 3.11088 (-0.00874)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_72.pth
#
#  > EPOCH: 12/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:35:09)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 3/6 -- GLOBAL_STEP: 75
#      | > loss: 3.36564  (3.32683)
#      | > log_mle: 0.53458  (0.54553)
#      | > loss_dur: 2.83106  (2.78130)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 9.58331  (9.54238)
#      | > current_lr: 0.00000
#      | > step_time: 0.74870  (0.67295)
#      | > loader_time: 0.40540  (0.36099)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00100)
#      | > avg_loss: 3.64969 (-0.01537)
#      | > avg_log_mle: 0.55373 (-0.00045)
#      | > avg_loss_dur: 3.09596 (-0.01491)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_78.pth
#
#  > EPOCH: 13/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:35:21)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00000)
#      | > avg_loss: 3.63668 (-0.01301)
#      | > avg_log_mle: 0.55321 (-0.00052)
#      | > avg_loss_dur: 3.08347 (-0.01249)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_84.pth
#
#  > EPOCH: 14/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:35:33)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00000)
#      | > avg_loss: 3.61751 (-0.01917)
#      | > avg_log_mle: 0.55262 (-0.00059)
#      | > avg_loss_dur: 3.06489 (-0.01858)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_90.pth
#
#  > EPOCH: 15/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:35:45)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00100)
#      | > avg_loss: 3.60008 (-0.01743)
#      | > avg_log_mle: 0.55196 (-0.00066)
#      | > avg_loss_dur: 3.04812 (-0.01677)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_96.pth
#
#  > EPOCH: 16/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:35:58)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 4/6 -- GLOBAL_STEP: 100
#      | > loss: 3.42811  (3.28860)
#      | > log_mle: 0.54805  (0.54450)
#      | > loss_dur: 2.88006  (2.74409)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 9.60170  (9.41167)
#      | > current_lr: 0.00000
#      | > step_time: 0.85180  (0.74463)
#      | > loader_time: 0.43940  (0.37756)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00100)
#      | > avg_loss: 3.57499 (-0.02509)
#      | > avg_log_mle: 0.55122 (-0.00074)
#      | > avg_loss_dur: 3.02376 (-0.02435)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_102.pth
#
#  > EPOCH: 17/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:36:10)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (-0.00000)
#      | > avg_loss: 3.55298 (-0.02201)
#      | > avg_log_mle: 0.55039 (-0.00083)
#      | > avg_loss_dur: 3.00259 (-0.02118)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_108.pth
#
#  > EPOCH: 18/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:36:21)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00100)
#      | > avg_loss: 3.53983 (-0.01315)
#      | > avg_log_mle: 0.54947 (-0.00093)
#      | > avg_loss_dur: 2.99036 (-0.01222)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_114.pth
#
#  > EPOCH: 19/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:36:34)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02402 (+0.00300)
#      | > avg_loss: 3.51210 (-0.02773)
#      | > avg_log_mle: 0.54844 (-0.00103)
#      | > avg_loss_dur: 2.96367 (-0.02670)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_120.pth
#
#  > EPOCH: 20/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:36:46)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 5/6 -- GLOBAL_STEP: 125
#      | > loss: 3.34568  (3.25832)
#      | > log_mle: 0.54602  (0.54170)
#      | > loss_dur: 2.79965  (2.71662)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 9.45068  (9.25562)
#      | > current_lr: 0.00000
#      | > step_time: 1.21590  (0.83036)
#      | > loader_time: 0.47940  (0.39927)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02002 (-0.00400)
#      | > avg_loss: 3.48918 (-0.02292)
#      | > avg_log_mle: 0.54729 (-0.00115)
#      | > avg_loss_dur: 2.94190 (-0.02177)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_126.pth
#
#  > EPOCH: 21/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:36:58)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02302 (+0.00300)
#      | > avg_loss: 3.46197 (-0.02721)
#      | > avg_log_mle: 0.54600 (-0.00128)
#      | > avg_loss_dur: 2.91597 (-0.02593)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_132.pth
#
#  > EPOCH: 22/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:37:10)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00200)
#      | > avg_loss: 3.42138 (-0.04059)
#      | > avg_log_mle: 0.54457 (-0.00143)
#      | > avg_loss_dur: 2.87681 (-0.03915)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_138.pth
#
#  > EPOCH: 23/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:37:22)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00000)
#      | > avg_loss: 3.38394 (-0.03744)
#      | > avg_log_mle: 0.54297 (-0.00160)
#      | > avg_loss_dur: 2.84098 (-0.03584)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_144.pth
#
#  > EPOCH: 24/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:37:34)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00100)
#      | > avg_loss: 3.34964 (-0.03430)
#      | > avg_log_mle: 0.54118 (-0.00179)
#      | > avg_loss_dur: 2.80846 (-0.03251)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_150.pth
#
#  > EPOCH: 25/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:37:46)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 0/6 -- GLOBAL_STEP: 150
#      | > loss: 2.96779  (2.96779)
#      | > log_mle: 0.52060  (0.52060)
#      | > loss_dur: 2.44718  (2.44718)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 8.27804  (8.27804)
#      | > current_lr: 0.00001
#      | > step_time: 0.59250  (0.59254)
#      | > loader_time: 0.28830  (0.28826)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00100)
#      | > avg_loss: 3.31382 (-0.03582)
#      | > avg_log_mle: 0.53917 (-0.00201)
#      | > avg_loss_dur: 2.77466 (-0.03381)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_156.pth
#
#  > EPOCH: 26/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:37:58)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00000)
#      | > avg_loss: 3.26695 (-0.04687)
#      | > avg_log_mle: 0.53692 (-0.00225)
#      | > avg_loss_dur: 2.73004 (-0.04462)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_162.pth
#
#  > EPOCH: 27/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:38:10)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00100)
#      | > avg_loss: 3.23243 (-0.03452)
#      | > avg_log_mle: 0.53440 (-0.00252)
#      | > avg_loss_dur: 2.69803 (-0.03200)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_168.pth
#
#  > EPOCH: 28/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:38:23)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02202 (+0.00000)
#      | > avg_loss: 3.20046 (-0.03197)
#      | > avg_log_mle: 0.53158 (-0.00282)
#      | > avg_loss_dur: 2.66888 (-0.02915)
#
#  > BEST MODEL : ./output\run-September-12-2022_01+31AM-3a2b985\best_model_174.pth
#
#  > EPOCH: 29/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 01:38:35)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 1/6 -- GLOBAL_STEP: 175
#      | > loss: 2.78433  (2.78433)
#      | > log_mle: 0.51948  (0.51948)
#      | > loss_dur: 2.26485  (2.26485)
#      | > amp_scaler: 16384.00000  (16384.00000)
#      | > grad_norm: 7.50739  (7.50739)
#      | > current_lr: 0.00001
#      | > step_time: 0.63360  (0.63358)
#      | > loader_time: 0.32630  (0.32630)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
# ...
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02101 (-0.00101)
#      | > avg_loss: 1.02956 (+0.13180)
#      | > avg_log_mle: 0.10147 (+0.04185)
#      | > avg_loss_dur: 0.92808 (+0.08995)
#
#
#  > EPOCH: 990/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:47:59)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02201 (+0.00100)
#      | > avg_loss: 1.02213 (-0.00743)
#      | > avg_log_mle: 0.06861 (-0.03286)
#      | > avg_loss_dur: 0.95352 (+0.02543)
#
#
#  > EPOCH: 991/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:48:15)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 4/6 -- GLOBAL_STEP: 5950
#      | > loss: -0.60146  (-0.68926)
#      | > log_mle: -0.66628  (-0.74702)
#      | > loss_dur: 0.06482  (0.05776)
#      | > amp_scaler: 8192.00000  (8192.00000)
#      | > grad_norm: 18.07539  (17.05776)
#      | > current_lr: 0.00025
#      | > step_time: 0.82270  (0.70914)
#      | > loader_time: 0.43640  (0.37559)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02001 (-0.00200)
#      | > avg_loss: 0.90014 (-0.12199)
#      | > avg_log_mle: 0.06964 (+0.00102)
#      | > avg_loss_dur: 0.83050 (-0.12301)
#
#
#  > EPOCH: 992/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:48:30)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02502 (+0.00501)
#      | > avg_loss: 0.89796 (-0.00218)
#      | > avg_log_mle: 0.07700 (+0.00736)
#      | > avg_loss_dur: 0.82097 (-0.00954)
#
#
#  > EPOCH: 993/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:48:45)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02101 (-0.00401)
#      | > avg_loss: 0.92046 (+0.02250)
#      | > avg_log_mle: 0.07477 (-0.00223)
#      | > avg_loss_dur: 0.84569 (+0.02473)
#
#
#  > EPOCH: 994/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:49:01)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02201 (+0.00100)
#      | > avg_loss: 1.01119 (+0.09073)
#      | > avg_log_mle: 0.05982 (-0.01494)
#      | > avg_loss_dur: 0.95136 (+0.10567)
#
#
#  > EPOCH: 995/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:49:17)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#    --> STEP: 5/6 -- GLOBAL_STEP: 5975
#      | > loss: -0.60855  (-0.67606)
#      | > log_mle: -0.67137  (-0.73664)
#      | > loss_dur: 0.06282  (0.06059)
#      | > amp_scaler: 8192.00000  (8192.00000)
#      | > grad_norm: 17.87324  (11.44311)
#      | > current_lr: 0.00025
#      | > step_time: 1.14300  (0.79372)
#      | > loader_time: 0.48340  (0.39776)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (-0.00099)
#      | > avg_loss: 1.00955 (-0.00164)
#      | > avg_log_mle: 0.08554 (+0.02572)
#      | > avg_loss_dur: 0.92400 (-0.02736)
#
#
#  > EPOCH: 996/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:49:32)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02401 (+0.00299)
#      | > avg_loss: 1.02762 (+0.01807)
#      | > avg_log_mle: 0.09032 (+0.00478)
#      | > avg_loss_dur: 0.93729 (+0.01329)
#
#
#  > EPOCH: 997/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:49:48)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02002 (-0.00399)
#      | > avg_loss: 0.92680 (-0.10082)
#      | > avg_log_mle: 0.07467 (-0.01565)
#      | > avg_loss_dur: 0.85213 (-0.08516)
#
#
#  > EPOCH: 998/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:50:04)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02102 (+0.00100)
#      | > avg_loss: 1.04177 (+0.11497)
#      | > avg_log_mle: 0.09731 (+0.02265)
#      | > avg_loss_dur: 0.94446 (+0.09232)
#
#
#  > EPOCH: 999/1000
#  --> ./output\run-September-12-2022_01+31AM-3a2b985
#
#  > TRAINING (2022-09-12 05:50:19)
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 377
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 8
#  | > Avg text length: 49.57029177718833
#  |
#  | > Max audio length: 140760.0
#  | > Min audio length: 26032.0
#  | > Avg audio length: 66934.28381962865
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: False
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en-us
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 3
#  | > Preprocessing samples
#  | > Max text length: 47
#  | > Min text length: 43
#  | > Avg text length: 45.0
#  |
#  | > Max audio length: 68366.0
#  | > Min audio length: 54072.0
#  | > Avg audio length: 63084.333333333336
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.02101 (-0.00001)
#      | > avg_loss: 0.94392 (-0.09785)
#      | > avg_log_mle: 0.10243 (+0.00511)
#      | > avg_loss_dur: 0.84149 (-0.10296)
