# %% [markdown]
# # Voice Cloning

# %% [markdown]
# I'll be attempting to make a voice cloning model using Coqui TTS and the TIMIT dataset. Documentation on how to use Coqui TTS can be found here: https://tts.readthedocs.io/en/latest/index.html#.

# %%
import os

from trainer import Trainer, TrainerArgs

from TTS.tts.configs.shared_configs import BaseDatasetConfig
from TTS.tts.configs.vits_config import VitsConfig
from TTS.tts.datasets import load_tts_samples
from TTS.tts.models.vits import Vits, VitsArgs, VitsAudioConfig
from TTS.tts.utils.speakers import SpeakerManager
from TTS.tts.utils.text.tokenizer import TTSTokenizer
from TTS.utils.audio import AudioProcessor
# Out:
# C:\Users\Chris\Anaconda3\envs\torch\lib\site-packages\torchaudio\extension\extension.py:13: UserWarning: torchaudio C++ extension is not available.
#   warnings.warn('torchaudio C++ extension is not available.')

# %% [markdown]
# # Data Preparation

# %%
dataset_path = 'D:\data\TIMIT\TRAIN'
output_path = './output'

# %% [markdown]
# I'll be using the vctk dataset config since it is already formatted for a multispeaker dataset. If you're planning on using this dataset config, your dataset needs to be configured in this way:
#
# /MyTTSDataset\
# &emsp;| -> /txt\
# &emsp;&emsp;&emsp;| -> /speaker\
# &emsp;&emsp;&emsp;&emsp;&emsp;| -> audio1.txt\
# &emsp;&emsp;&emsp;&emsp;&emsp;| -> audio2.txt\
# &emsp;&emsp;&emsp;&emsp;&emsp;| -> ...\
# &emsp;| -> /wav48\
# &emsp;&emsp;&emsp;| -> /speaker\
# &emsp;&emsp;&emsp;&emsp;&emsp;| -> audio1.wav\
# &emsp;&emsp;&emsp;&emsp;&emsp;| -> audio2.wav\
# &emsp;&emsp;&emsp;&emsp;&emsp;| -> ...

# %%
# define dataset config
# need to use vctk_old format if using wav files instead of flac

dataset_config = BaseDatasetConfig(
    name="vctk_old", meta_file_train="", language="en-us", path=dataset_path
)

# %%
audio_config = VitsAudioConfig(
    sample_rate=22050, win_length=1024, hop_length=256, num_mels=80, mel_fmin=0, mel_fmax=None
)

# %%
vitsArgs = VitsArgs(
    use_speaker_embedding=True,
)

# %%
config = VitsConfig(
    model_args=vitsArgs,
    audio=audio_config,
    run_name="vits_vctk",
    batch_size=32,
    eval_batch_size=16,
    batch_group_size=5,
    num_loader_workers=4,
    num_eval_loader_workers=4,
    run_eval=True,
    test_delay_epochs=-1,
    epochs=1000,
    text_cleaner="english_cleaners",
    use_phonemes=True,
    phoneme_language="en",
    phoneme_cache_path=os.path.join(output_path, "phoneme_cache"),
    compute_input_seq_cache=True,
    print_step=25,
    print_eval=False,
    mixed_precision=True,
    max_text_len=325,  # change this if you have a larger VRAM than 16GB
    output_path=output_path,
    datasets=[dataset_config],
    cudnn_benchmark=False,
)

# %%
# INITIALIZE THE AUDIO PROCESSOR
# Audio processor is used for feature extraction and audio I/O.
# It mainly serves to the dataloader and the training loggers.
ap = AudioProcessor.init_from_config(config)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024

# %%
# INITIALIZE THE TOKENIZER
# Tokenizer is used to convert text to sequences of token IDs.
# config is updated with the default characters if not defined in the config.
tokenizer, config = TTSTokenizer.init_from_config(config)

# %%
# LOAD DATA SAMPLES
# Each sample is a list of ```[text, audio_file_path, speaker_name]```

train_samples, eval_samples = load_tts_samples(
    dataset_config,
    eval_split=True,
    eval_split_max_size=config.eval_split_max_size,
    eval_split_size=config.eval_split_size,
)
# Out:
#  | > Found 2580 files in D:\data\TIMIT\TRAIN

# %%
# init speaker manager for multi-speaker training
# it maps speaker-id to speaker-name in the model and data-loader
speaker_manager = SpeakerManager()
speaker_manager.set_ids_from_data(train_samples + eval_samples, parse_key="speaker_name")
config.model_args.num_speakers = speaker_manager.num_speakers

# %%
# init model
model = Vits(config, ap, tokenizer, speaker_manager)
# Out:
#  > initialization of speaker-embedding layers.

# %%
# init the trainer and 🚀
trainer = Trainer(
    TrainerArgs(),
    config,
    output_path,
    model=model,
    train_samples=train_samples,
    eval_samples=eval_samples,
)
trainer.fit()
# Out:
#  > Using CUDA: True
#  > Number of GPUs: 1
#
#  > Model has 86476460 parameters
#
#  > EPOCH: 0/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
#  > `speakers.pth` is saved to ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\speakers.pth.
#  > `speakers_file` is updated in the config.json.
# [*] Pre-computing phonemes...
#   0%|          | 1/2555 [00:00<24:54,  1.71it/s]
# ['<BLNK>', 'b', '<BLNK>', 'ɪ', '<BLNK>', 'f', '<BLNK>', 'ɔ', '<BLNK>', 'ɹ', '<BLNK>', ' ', '<BLNK>', 'm', '<BLNK>', 'ʌ', '<BLNK>', 't', '<BLNK>', '͡', '<BLNK>', 'ʃ', '<BLNK>', ' ', '<BLNK>', 'l', '<BLNK>', 'ɔ', '<BLNK>', 'ŋ', '<BLNK>', 'ɡ', '<BLNK>', 'ɚ', '<BLNK>', ' ', '<BLNK>', 'ð', '<BLNK>', 'ə', '<BLNK>', ' ', '<BLNK>', 'm', '<BLNK>', 'ɚ', '<BLNK>', 'i', '<BLNK>', 'n', '<BLNK>', ' ', '<BLNK>', 'k', '<BLNK>', 'w', '<BLNK>', 'a', '<BLNK>', 'ɪ', '<BLNK>', 'ə', '<BLNK>', 't', '<BLNK>', 'ɪ', '<BLNK>', 'd', '<BLNK>', ' ', '<BLNK>', 'd', '<BLNK>', 'a', '<BLNK>', 'ʊ', '<BLNK>', 'n', '<BLNK>', '.', '<BLNK>']
#  [!] Character '͡' not found in the vocabulary. Discarding it.
# 100%|██████████| 2555/2555 [01:35<00:00, 26.83it/s]
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 02:48:32)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
# C:\Users\Chris\Anaconda3\envs\torch\lib\site-packages\torch\functional.py:580: UserWarning: stft will soon require the return_complex parameter be given for real inputs, and will further require that return_complex=True in a future PyTorch release. (Triggered internally at  ..\aten\src\ATen\native\SpectralOps.cpp:639.)
#   return _VF.stft(input, n_fft, hop_length, win_length, window,  # type: ignore
#
#    --> STEP: 0/80 -- GLOBAL_STEP: 0
#      | > loss_disc: 6.11368  (6.11368)
#      | > loss_disc_real_0: 1.05477  (1.05477)
#      | > loss_disc_real_1: 0.98233  (0.98233)
#      | > loss_disc_real_2: 1.00725  (1.00725)
#      | > loss_disc_real_3: 1.03027  (1.03027)
#      | > loss_disc_real_4: 1.02319  (1.02319)
#      | > loss_disc_real_5: 1.01460  (1.01460)
#      | > loss_0: 6.11368  (6.11368)
#      | > grad_norm_0: 0.00000  (0.00000)
#      | > loss_gen: 6.11202  (6.11202)
#      | > loss_kl: 172.06483  (172.06483)
#      | > loss_feat: 0.22016  (0.22016)
#      | > loss_mel: 83.79940  (83.79940)
#      | > loss_duration: 1.68916  (1.68916)
#      | > amp_scaler: 32768.00000  (32768.00000)
#      | > loss_1: 263.88559  (263.88559)
#      | > grad_norm_1: 0.00000  (0.00000)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 19.65040  (19.65043)
#      | > loader_time: 26.86980  (26.86977)
#
#
#    --> STEP: 25/80 -- GLOBAL_STEP: 25
#      | > loss_disc: 3.01995  (3.44759)
#      | > loss_disc_real_0: 0.28325  (0.34162)
#      | > loss_disc_real_1: 0.25595  (0.34232)
#      | > loss_disc_real_2: 0.26776  (0.35027)
#      | > loss_disc_real_3: 0.26385  (0.36374)
#      | > loss_disc_real_4: 0.28173  (0.37143)
#      | > loss_disc_real_5: 0.24203  (0.36581)
#      | > loss_0: 3.01995  (3.44759)
#      | > grad_norm_0: 0.48381  (2.45216)
#      | > loss_gen: 1.54455  (1.96538)
#      | > loss_kl: 15.24009  (60.78401)
#      | > loss_feat: 0.15565  (0.14883)
#      | > loss_mel: 53.82956  (65.43764)
#      | > loss_duration: 1.66682  (1.62479)
#      | > amp_scaler: 256.00000  (2048.00000)
#      | > loss_1: 72.43666  (129.96065)
#      | > grad_norm_1: 127.52979  (221.00404)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 6.13510  (5.90270)
#      | > loader_time: 0.00900  (0.01381)
#
#
#    --> STEP: 50/80 -- GLOBAL_STEP: 50
#      | > loss_disc: 3.04367  (3.20979)
#      | > loss_disc_real_0: 0.25461  (0.29851)
#      | > loss_disc_real_1: 0.26161  (0.29470)
#      | > loss_disc_real_2: 0.24784  (0.30096)
#      | > loss_disc_real_3: 0.17236  (0.30560)
#      | > loss_disc_real_4: 0.26986  (0.31037)
#      | > loss_disc_real_5: 0.34458  (0.30510)
#      | > loss_0: 3.04367  (3.20979)
#      | > grad_norm_0: 4.90613  (2.83600)
#      | > loss_gen: 1.65469  (1.78098)
#      | > loss_kl: 5.37361  (34.92236)
#      | > loss_feat: 0.06775  (0.23849)
#      | > loss_mel: 46.02137  (58.05037)
#      | > loss_duration: 1.78299  (1.65895)
#      | > amp_scaler: 256.00000  (1152.00000)
#      | > loss_1: 54.90040  (96.65117)
#      | > grad_norm_1: 147.92747  (240.93033)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 6.21490  (5.95011)
#      | > loader_time: 0.01100  (0.01382)
#
#
#    --> STEP: 75/80 -- GLOBAL_STEP: 75
#      | > loss_disc: 3.05683  (3.17547)
#      | > loss_disc_real_0: 0.24715  (0.28275)
#      | > loss_disc_real_1: 0.26797  (0.28674)
#      | > loss_disc_real_2: 0.24400  (0.28689)
#      | > loss_disc_real_3: 0.25537  (0.29572)
#      | > loss_disc_real_4: 0.28355  (0.29981)
#      | > loss_disc_real_5: 0.26366  (0.29327)
#      | > loss_0: 3.05683  (3.17547)
#      | > grad_norm_0: 0.84743  (2.50698)
#      | > loss_gen: 1.49901  (1.69376)
#      | > loss_kl: 3.36689  (24.71993)
#      | > loss_feat: 0.23945  (0.25552)
#      | > loss_mel: 42.65882  (53.97473)
#      | > loss_duration: 1.81972  (1.69489)
#      | > amp_scaler: 256.00000  (853.33333)
#      | > loss_1: 49.58390  (82.33885)
#      | > grad_norm_1: 85.90588  (235.37422)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 6.16050  (5.98575)
#      | > loader_time: 0.01400  (0.01467)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01101 (+0.00000)
#      | > avg_loss_disc: 2.99067 (+0.00000)
#      | > avg_loss_disc_real_0: 0.24615 (+0.00000)
#      | > avg_loss_disc_real_1: 0.18960 (+0.00000)
#      | > avg_loss_disc_real_2: 0.31744 (+0.00000)
#      | > avg_loss_disc_real_3: 0.23929 (+0.00000)
#      | > avg_loss_disc_real_4: 0.26313 (+0.00000)
#      | > avg_loss_disc_real_5: 0.25094 (+0.00000)
#      | > avg_loss_0: 2.99067 (+0.00000)
#      | > avg_loss_gen: 1.53253 (+0.00000)
#      | > avg_loss_kl: 2.42016 (+0.00000)
#      | > avg_loss_feat: 0.17695 (+0.00000)
#      | > avg_loss_mel: 44.02678 (+0.00000)
#      | > avg_loss_duration: 2.08415 (+0.00000)
#      | > avg_loss_1: 50.24057 (+0.00000)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_80.pth
#
#  > EPOCH: 1/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 02:57:44)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 20/80 -- GLOBAL_STEP: 100
#      | > loss_disc: 3.01141  (3.07165)
#      | > loss_disc_real_0: 0.24578  (0.25090)
#      | > loss_disc_real_1: 0.26513  (0.26752)
#      | > loss_disc_real_2: 0.27293  (0.25913)
#      | > loss_disc_real_3: 0.23149  (0.25820)
#      | > loss_disc_real_4: 0.24993  (0.25593)
#      | > loss_disc_real_5: 0.22031  (0.25331)
#      | > loss_0: 3.01141  (3.07165)
#      | > grad_norm_0: 0.92365  (2.30652)
#      | > loss_gen: 1.47746  (1.51351)
#      | > loss_kl: 2.29899  (2.90413)
#      | > loss_feat: 0.40550  (0.35985)
#      | > loss_mel: 43.20527  (42.79910)
#      | > loss_duration: 1.75414  (1.71961)
#      | > amp_scaler: 128.00000  (147.20000)
#      | > loss_1: 49.14136  (49.29620)
#      | > grad_norm_1: 130.37881  (225.38504)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.81250  (3.72100)
#      | > loader_time: 0.01000  (0.00866)
#
#
#    --> STEP: 45/80 -- GLOBAL_STEP: 125
#      | > loss_disc: 2.94522  (3.01591)
#      | > loss_disc_real_0: 0.15885  (0.23685)
#      | > loss_disc_real_1: 0.22819  (0.26058)
#      | > loss_disc_real_2: 0.27253  (0.25598)
#      | > loss_disc_real_3: 0.25391  (0.25078)
#      | > loss_disc_real_4: 0.24495  (0.25090)
#      | > loss_disc_real_5: 0.23200  (0.25461)
#      | > loss_0: 2.94522  (3.01591)
#      | > grad_norm_0: 3.76663  (2.58579)
#      | > loss_gen: 1.70811  (1.54903)
#      | > loss_kl: 2.36997  (2.60936)
#      | > loss_feat: 0.38590  (0.48111)
#      | > loss_mel: 40.83451  (41.96835)
#      | > loss_duration: 1.81501  (1.74770)
#      | > amp_scaler: 128.00000  (136.53333)
#      | > loss_1: 47.11350  (48.35555)
#      | > grad_norm_1: 216.63458  (205.46289)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.83920  (3.79249)
#      | > loader_time: 0.01300  (0.00999)
#
#
#    --> STEP: 70/80 -- GLOBAL_STEP: 150
#      | > loss_disc: 2.81273  (2.97920)
#      | > loss_disc_real_0: 0.08371  (0.20936)
#      | > loss_disc_real_1: 0.26049  (0.26133)
#      | > loss_disc_real_2: 0.25688  (0.25613)
#      | > loss_disc_real_3: 0.25953  (0.25505)
#      | > loss_disc_real_4: 0.27367  (0.25717)
#      | > loss_disc_real_5: 0.27599  (0.26063)
#      | > loss_0: 2.81273  (2.97920)
#      | > grad_norm_0: 1.59379  (3.15829)
#      | > loss_gen: 1.75316  (1.60527)
#      | > loss_kl: 1.97837  (2.41716)
#      | > loss_feat: 1.23818  (0.66306)
#      | > loss_mel: 40.47655  (41.83475)
#      | > loss_duration: 1.80902  (1.77751)
#      | > amp_scaler: 128.00000  (133.48571)
#      | > loss_1: 47.25529  (48.29777)
#      | > grad_norm_1: 87.78821  (194.98874)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 4.05580  (3.84468)
#      | > loader_time: 0.01500  (0.01095)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00200)
#      | > avg_loss_disc: 2.81389 (-0.17677)
#      | > avg_loss_disc_real_0: 0.11632 (-0.12983)
#      | > avg_loss_disc_real_1: 0.30232 (+0.11273)
#      | > avg_loss_disc_real_2: 0.25000 (-0.06744)
#      | > avg_loss_disc_real_3: 0.25131 (+0.01202)
#      | > avg_loss_disc_real_4: 0.18194 (-0.08119)
#      | > avg_loss_disc_real_5: 0.23990 (-0.01104)
#      | > avg_loss_0: 2.81389 (-0.17677)
#      | > avg_loss_gen: 1.77927 (+0.24674)
#      | > avg_loss_kl: 1.57916 (-0.84100)
#      | > avg_loss_feat: 0.99965 (+0.82270)
#      | > avg_loss_mel: 40.68757 (-3.33921)
#      | > avg_loss_duration: 2.07579 (-0.00836)
#      | > avg_loss_1: 47.12144 (-3.11913)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_160.pth
#
#  > EPOCH: 2/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:03:43)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 15/80 -- GLOBAL_STEP: 175
#      | > loss_disc: 2.70822  (2.74839)
#      | > loss_disc_real_0: 0.08817  (0.11828)
#      | > loss_disc_real_1: 0.24986  (0.24931)
#      | > loss_disc_real_2: 0.25055  (0.24961)
#      | > loss_disc_real_3: 0.24942  (0.24694)
#      | > loss_disc_real_4: 0.25395  (0.25074)
#      | > loss_disc_real_5: 0.25324  (0.23898)
#      | > loss_0: 2.70822  (2.74839)
#      | > grad_norm_0: 2.53157  (6.01052)
#      | > loss_gen: 1.88771  (1.89132)
#      | > loss_kl: 1.71137  (1.94142)
#      | > loss_feat: 1.42440  (1.21705)
#      | > loss_mel: 38.74998  (39.95965)
#      | > loss_duration: 1.69472  (1.74811)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 45.46818  (46.75755)
#      | > grad_norm_1: 108.47432  (162.58652)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.73160  (3.70142)
#      | > loader_time: 0.01000  (0.00841)
#
#
#    --> STEP: 40/80 -- GLOBAL_STEP: 200
#      | > loss_disc: 2.71678  (2.73990)
#      | > loss_disc_real_0: 0.11673  (0.10852)
#      | > loss_disc_real_1: 0.25470  (0.25229)
#      | > loss_disc_real_2: 0.23295  (0.25082)
#      | > loss_disc_real_3: 0.23160  (0.25102)
#      | > loss_disc_real_4: 0.24536  (0.25359)
#      | > loss_disc_real_5: 0.22856  (0.25034)
#      | > loss_0: 2.71678  (2.73990)
#      | > grad_norm_0: 2.37774  (5.94422)
#      | > loss_gen: 1.90156  (1.92243)
#      | > loss_kl: 2.25581  (1.95774)
#      | > loss_feat: 1.29921  (1.33963)
#      | > loss_mel: 37.52600  (39.37236)
#      | > loss_duration: 1.76900  (1.76555)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 44.75159  (46.35771)
#      | > grad_norm_1: 77.08831  (149.00542)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.88470  (3.74948)
#      | > loader_time: 0.01200  (0.00966)
#
#
#    --> STEP: 65/80 -- GLOBAL_STEP: 225
#      | > loss_disc: 2.92061  (2.76071)
#      | > loss_disc_real_0: 0.30176  (0.12831)
#      | > loss_disc_real_1: 0.24287  (0.25095)
#      | > loss_disc_real_2: 0.24715  (0.25052)
#      | > loss_disc_real_3: 0.23007  (0.24863)
#      | > loss_disc_real_4: 0.24086  (0.25117)
#      | > loss_disc_real_5: 0.23249  (0.24839)
#      | > loss_0: 2.92061  (2.76071)
#      | > grad_norm_0: 9.74287  (6.41943)
#      | > loss_gen: 1.66451  (1.87916)
#      | > loss_kl: 1.67127  (2.01781)
#      | > loss_feat: 0.66875  (1.22449)
#      | > loss_mel: 35.79203  (38.39404)
#      | > loss_duration: 1.81629  (1.79448)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 41.61285  (45.30997)
#      | > grad_norm_1: 120.07083  (148.50018)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 4.00870  (3.80894)
#      | > loader_time: 0.01400  (0.01067)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss_disc: 3.07179 (+0.25789)
#      | > avg_loss_disc_real_0: 0.27248 (+0.15616)
#      | > avg_loss_disc_real_1: 0.25592 (-0.04640)
#      | > avg_loss_disc_real_2: 0.24913 (-0.00087)
#      | > avg_loss_disc_real_3: 0.28359 (+0.03228)
#      | > avg_loss_disc_real_4: 0.25089 (+0.06895)
#      | > avg_loss_disc_real_5: 0.26192 (+0.02202)
#      | > avg_loss_0: 3.07179 (+0.25789)
#      | > avg_loss_gen: 1.54680 (-0.23247)
#      | > avg_loss_kl: 1.69688 (+0.11772)
#      | > avg_loss_feat: 0.46630 (-0.53336)
#      | > avg_loss_mel: 36.20634 (-4.48122)
#      | > avg_loss_duration: 1.99865 (-0.07714)
#      | > avg_loss_1: 41.91497 (-5.20647)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_240.pth
#
#  > EPOCH: 3/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:09:36)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 10/80 -- GLOBAL_STEP: 250
#      | > loss_disc: 2.84081  (2.95717)
#      | > loss_disc_real_0: 0.15214  (0.25659)
#      | > loss_disc_real_1: 0.24419  (0.24495)
#      | > loss_disc_real_2: 0.25628  (0.24866)
#      | > loss_disc_real_3: 0.27792  (0.24230)
#      | > loss_disc_real_4: 0.24324  (0.24343)
#      | > loss_disc_real_5: 0.23603  (0.23780)
#      | > loss_0: 2.84081  (2.95717)
#      | > grad_norm_0: 4.79401  (5.57308)
#      | > loss_gen: 1.53450  (1.55451)
#      | > loss_kl: 1.83119  (2.02393)
#      | > loss_feat: 0.57709  (0.46294)
#      | > loss_mel: 33.04788  (34.49731)
#      | > loss_duration: 1.71335  (1.75774)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 38.70401  (40.29643)
#      | > grad_norm_1: 141.54292  (162.55446)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.72220  (3.68935)
#      | > loader_time: 0.01000  (0.00861)
#
#
#    --> STEP: 35/80 -- GLOBAL_STEP: 275
#      | > loss_disc: 2.87061  (2.92550)
#      | > loss_disc_real_0: 0.26595  (0.23293)
#      | > loss_disc_real_1: 0.24904  (0.24714)
#      | > loss_disc_real_2: 0.24869  (0.24886)
#      | > loss_disc_real_3: 0.31227  (0.25412)
#      | > loss_disc_real_4: 0.23484  (0.24506)
#      | > loss_disc_real_5: 0.25042  (0.24331)
#      | > loss_0: 2.87061  (2.92550)
#      | > grad_norm_0: 6.76068  (9.44487)
#      | > loss_gen: 1.66289  (1.65197)
#      | > loss_kl: 1.91456  (1.93614)
#      | > loss_feat: 0.60064  (0.56289)
#      | > loss_mel: 34.21486  (33.53735)
#      | > loss_duration: 1.89079  (1.76492)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 40.28374  (39.45326)
#      | > grad_norm_1: 236.52194  (249.34351)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.80710  (3.74306)
#      | > loader_time: 0.01100  (0.00941)
#
#
#    --> STEP: 60/80 -- GLOBAL_STEP: 300
#      | > loss_disc: 2.93024  (2.94695)
#      | > loss_disc_real_0: 0.30125  (0.24198)
#      | > loss_disc_real_1: 0.24299  (0.24817)
#      | > loss_disc_real_2: 0.26090  (0.24994)
#      | > loss_disc_real_3: 0.22767  (0.25137)
#      | > loss_disc_real_4: 0.24315  (0.24736)
#      | > loss_disc_real_5: 0.23863  (0.24687)
#      | > loss_0: 2.93024  (2.94695)
#      | > grad_norm_0: 3.37891  (8.14537)
#      | > loss_gen: 1.59425  (1.62394)
#      | > loss_kl: 1.86767  (1.91333)
#      | > loss_feat: 0.43577  (0.50779)
#      | > loss_mel: 33.35184  (33.40070)
#      | > loss_duration: 1.92285  (1.79331)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 39.17238  (39.23905)
#      | > grad_norm_1: 322.85419  (224.36519)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.96500  (3.80013)
#      | > loader_time: 0.01200  (0.01044)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss_disc: 3.18682 (+0.11503)
#      | > avg_loss_disc_real_0: 0.42324 (+0.15076)
#      | > avg_loss_disc_real_1: 0.34581 (+0.08989)
#      | > avg_loss_disc_real_2: 0.24111 (-0.00802)
#      | > avg_loss_disc_real_3: 0.27120 (-0.01239)
#      | > avg_loss_disc_real_4: 0.16745 (-0.08343)
#      | > avg_loss_disc_real_5: 0.26542 (+0.00350)
#      | > avg_loss_0: 3.18682 (+0.11503)
#      | > avg_loss_gen: 1.57898 (+0.03218)
#      | > avg_loss_kl: 1.44568 (-0.25120)
#      | > avg_loss_feat: 0.55991 (+0.09362)
#      | > avg_loss_mel: 32.08495 (-4.12140)
#      | > avg_loss_duration: 1.97502 (-0.02363)
#      | > avg_loss_1: 37.64454 (-4.27043)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_320.pth
#
#  > EPOCH: 4/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:15:44)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 5/80 -- GLOBAL_STEP: 325
#      | > loss_disc: 2.91549  (2.96087)
#      | > loss_disc_real_0: 0.23185  (0.22413)
#      | > loss_disc_real_1: 0.28585  (0.26384)
#      | > loss_disc_real_2: 0.23617  (0.25562)
#      | > loss_disc_real_3: 0.28903  (0.24814)
#      | > loss_disc_real_4: 0.20400  (0.27601)
#      | > loss_disc_real_5: 0.18648  (0.23771)
#      | > loss_0: 2.91549  (2.96087)
#      | > grad_norm_0: 4.44181  (7.04678)
#      | > loss_gen: 1.47178  (1.56879)
#      | > loss_kl: 1.90361  (1.82830)
#      | > loss_feat: 0.35855  (0.40895)
#      | > loss_mel: 31.23132  (32.65712)
#      | > loss_duration: 1.78754  (1.77980)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 36.75280  (38.24296)
#      | > grad_norm_1: 283.18399  (184.72749)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.76960  (3.67794)
#      | > loader_time: 0.00800  (0.00801)
#
#
#    --> STEP: 30/80 -- GLOBAL_STEP: 350
#      | > loss_disc: 2.66527  (2.85263)
#      | > loss_disc_real_0: 0.18355  (0.19653)
#      | > loss_disc_real_1: 0.23009  (0.24715)
#      | > loss_disc_real_2: 0.25122  (0.25091)
#      | > loss_disc_real_3: 0.26878  (0.24531)
#      | > loss_disc_real_4: 0.23121  (0.25120)
#      | > loss_disc_real_5: 0.22351  (0.24120)
#      | > loss_0: 2.66527  (2.85263)
#      | > grad_norm_0: 13.21994  (7.50868)
#      | > loss_gen: 1.68991  (1.64560)
#      | > loss_kl: 1.85482  (1.81289)
#      | > loss_feat: 1.18812  (0.64225)
#      | > loss_mel: 30.21312  (31.90624)
#      | > loss_duration: 1.80473  (1.76013)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 36.75070  (37.76712)
#      | > grad_norm_1: 134.66566  (218.19052)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.78050  (3.73631)
#      | > loader_time: 0.00900  (0.00948)
#
#
#    --> STEP: 55/80 -- GLOBAL_STEP: 375
#      | > loss_disc: 2.97256  (2.90697)
#      | > loss_disc_real_0: 0.27393  (0.21715)
#      | > loss_disc_real_1: 0.24517  (0.24999)
#      | > loss_disc_real_2: 0.25645  (0.25080)
#      | > loss_disc_real_3: 0.19697  (0.24800)
#      | > loss_disc_real_4: 0.23491  (0.24963)
#      | > loss_disc_real_5: 0.23862  (0.24701)
#      | > loss_0: 2.97256  (2.90697)
#      | > grad_norm_0: 6.07844  (7.84643)
#      | > loss_gen: 1.67199  (1.63710)
#      | > loss_kl: 1.81077  (1.78617)
#      | > loss_feat: 0.58905  (0.60427)
#      | > loss_mel: 31.57585  (31.85299)
#      | > loss_duration: 1.85261  (1.78976)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 37.50027  (37.67028)
#      | > grad_norm_1: 244.46417  (213.91814)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.89340  (3.78632)
#      | > loader_time: 0.01300  (0.01043)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (+0.00100)
#      | > avg_loss_disc: 2.94327 (-0.24355)
#      | > avg_loss_disc_real_0: 0.20249 (-0.22075)
#      | > avg_loss_disc_real_1: 0.24687 (-0.09893)
#      | > avg_loss_disc_real_2: 0.26396 (+0.02285)
#      | > avg_loss_disc_real_3: 0.26885 (-0.00235)
#      | > avg_loss_disc_real_4: 0.18107 (+0.01361)
#      | > avg_loss_disc_real_5: 0.30917 (+0.04375)
#      | > avg_loss_0: 2.94327 (-0.24355)
#      | > avg_loss_gen: 1.55228 (-0.02670)
#      | > avg_loss_kl: 1.60917 (+0.16350)
#      | > avg_loss_feat: 0.50594 (-0.05397)
#      | > avg_loss_mel: 29.71990 (-2.36505)
#      | > avg_loss_duration: 1.96706 (-0.00796)
#      | > avg_loss_1: 35.35435 (-2.29018)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_400.pth
#
#  > EPOCH: 5/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:21:44)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 0/80 -- GLOBAL_STEP: 400
#      | > loss_disc: 2.93410  (2.93410)
#      | > loss_disc_real_0: 0.20164  (0.20164)
#      | > loss_disc_real_1: 0.24692  (0.24692)
#      | > loss_disc_real_2: 0.26419  (0.26419)
#      | > loss_disc_real_3: 0.26897  (0.26897)
#      | > loss_disc_real_4: 0.17975  (0.17975)
#      | > loss_disc_real_5: 0.31079  (0.31079)
#      | > loss_0: 2.93410  (2.93410)
#      | > grad_norm_0: 12.41704  (12.41704)
#      | > loss_gen: 1.53848  (1.53848)
#      | > loss_kl: 1.50734  (1.50734)
#      | > loss_feat: 0.52665  (0.52665)
#      | > loss_mel: 31.63449  (31.63449)
#      | > loss_duration: 1.81281  (1.81281)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 37.01978  (37.01978)
#      | > grad_norm_1: 124.51566  (124.51566)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.68040  (3.68035)
#      | > loader_time: 23.72990  (23.72993)
#
#
#    --> STEP: 25/80 -- GLOBAL_STEP: 425
#      | > loss_disc: 2.89359  (2.87923)
#      | > loss_disc_real_0: 0.24118  (0.22853)
#      | > loss_disc_real_1: 0.20661  (0.24602)
#      | > loss_disc_real_2: 0.24794  (0.24996)
#      | > loss_disc_real_3: 0.38139  (0.24623)
#      | > loss_disc_real_4: 0.30603  (0.24784)
#      | > loss_disc_real_5: 0.24957  (0.24015)
#      | > loss_0: 2.89359  (2.87923)
#      | > grad_norm_0: 13.97705  (11.16156)
#      | > loss_gen: 1.97700  (1.67661)
#      | > loss_kl: 1.52259  (1.72142)
#      | > loss_feat: 0.62210  (0.68315)
#      | > loss_mel: 29.51652  (30.82283)
#      | > loss_duration: 1.80280  (1.75795)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 35.44101  (36.66196)
#      | > grad_norm_1: 210.19905  (214.11046)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.78140  (3.72061)
#      | > loader_time: 0.01100  (0.00897)
#
#
#    --> STEP: 50/80 -- GLOBAL_STEP: 450
#      | > loss_disc: 2.81532  (2.91601)
#      | > loss_disc_real_0: 0.16725  (0.23980)
#      | > loss_disc_real_1: 0.26830  (0.25055)
#      | > loss_disc_real_2: 0.26151  (0.25005)
#      | > loss_disc_real_3: 0.25170  (0.24781)
#      | > loss_disc_real_4: 0.22611  (0.25425)
#      | > loss_disc_real_5: 0.18271  (0.24696)
#      | > loss_0: 2.81532  (2.91601)
#      | > grad_norm_0: 6.68990  (12.47837)
#      | > loss_gen: 1.56506  (1.66806)
#      | > loss_kl: 1.89897  (1.72245)
#      | > loss_feat: 0.60017  (0.66797)
#      | > loss_mel: 29.75905  (30.77807)
#      | > loss_duration: 1.90533  (1.78853)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 35.72858  (36.62507)
#      | > grad_norm_1: 153.92523  (202.37151)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.88210  (3.77573)
#      | > loader_time: 0.01200  (0.00991)
#
#
#    --> STEP: 75/80 -- GLOBAL_STEP: 475
#      | > loss_disc: 2.96904  (2.89525)
#      | > loss_disc_real_0: 0.27058  (0.23125)
#      | > loss_disc_real_1: 0.23455  (0.24888)
#      | > loss_disc_real_2: 0.18984  (0.25397)
#      | > loss_disc_real_3: 0.22342  (0.24652)
#      | > loss_disc_real_4: 0.28430  (0.24983)
#      | > loss_disc_real_5: 0.37111  (0.24712)
#      | > loss_0: 2.96904  (2.89525)
#      | > grad_norm_0: 11.86197  (12.45079)
#      | > loss_gen: 1.91370  (1.68541)
#      | > loss_kl: 1.74081  (1.71785)
#      | > loss_feat: 0.80075  (0.69778)
#      | > loss_mel: 30.25653  (30.69365)
#      | > loss_duration: 1.88969  (1.81033)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 36.60148  (36.60503)
#      | > grad_norm_1: 209.23886  (222.89941)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 4.39310  (3.84682)
#      | > loader_time: 0.01300  (0.01114)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (-0.00000)
#      | > avg_loss_disc: 2.88226 (-0.06101)
#      | > avg_loss_disc_real_0: 0.16962 (-0.03287)
#      | > avg_loss_disc_real_1: 0.27900 (+0.03213)
#      | > avg_loss_disc_real_2: 0.22622 (-0.03774)
#      | > avg_loss_disc_real_3: 0.22819 (-0.04066)
#      | > avg_loss_disc_real_4: 0.28356 (+0.10250)
#      | > avg_loss_disc_real_5: 0.26105 (-0.04812)
#      | > avg_loss_0: 2.88226 (-0.06101)
#      | > avg_loss_gen: 1.59592 (+0.04364)
#      | > avg_loss_kl: 1.27087 (-0.33830)
#      | > avg_loss_feat: 0.44323 (-0.06271)
#      | > avg_loss_mel: 27.89806 (-1.82184)
#      | > avg_loss_duration: 1.95886 (-0.00820)
#      | > avg_loss_1: 33.16693 (-2.18742)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_480.pth
#
#  > EPOCH: 6/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:27:43)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 20/80 -- GLOBAL_STEP: 500
#      | > loss_disc: 2.89324  (2.77882)
#      | > loss_disc_real_0: 0.22289  (0.17144)
#      | > loss_disc_real_1: 0.26583  (0.24808)
#      | > loss_disc_real_2: 0.25108  (0.24841)
#      | > loss_disc_real_3: 0.32476  (0.25096)
#      | > loss_disc_real_4: 0.28794  (0.24619)
#      | > loss_disc_real_5: 0.31851  (0.24594)
#      | > loss_0: 2.89324  (2.77882)
#      | > grad_norm_0: 12.86797  (10.30196)
#      | > loss_gen: 1.72059  (1.76612)
#      | > loss_kl: 1.64256  (1.72538)
#      | > loss_feat: 0.92375  (0.96654)
#      | > loss_mel: 29.73773  (29.96533)
#      | > loss_duration: 1.75782  (1.75281)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 35.78247  (36.17618)
#      | > grad_norm_1: 159.38362  (236.48839)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.62730  (3.74319)
#      | > loader_time: 0.01000  (0.00856)
#
#
#    --> STEP: 45/80 -- GLOBAL_STEP: 525
#      | > loss_disc: 3.04211  (2.92344)
#      | > loss_disc_real_0: 0.28469  (0.21224)
#      | > loss_disc_real_1: 0.17852  (0.26355)
#      | > loss_disc_real_2: 0.26092  (0.24771)
#      | > loss_disc_real_3: 0.48916  (0.25439)
#      | > loss_disc_real_4: 0.24056  (0.25622)
#      | > loss_disc_real_5: 0.28924  (0.29057)
#      | > loss_0: 3.04211  (2.92344)
#      | > grad_norm_0: 18.43947  (21.24495)
#      | > loss_gen: 2.00381  (1.86185)
#      | > loss_kl: 1.75670  (1.70549)
#      | > loss_feat: 0.65159  (1.02129)
#      | > loss_mel: 31.79966  (30.48218)
#      | > loss_duration: 1.87325  (1.77906)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 38.08501  (36.84987)
#      | > grad_norm_1: 116.24612  (236.88882)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.83860  (3.79793)
#      | > loader_time: 0.01100  (0.00972)
#
#
#    --> STEP: 70/80 -- GLOBAL_STEP: 550
#      | > loss_disc: 2.88783  (2.92709)
#      | > loss_disc_real_0: 0.21403  (0.22040)
#      | > loss_disc_real_1: 0.25202  (0.26287)
#      | > loss_disc_real_2: 0.24152  (0.24781)
#      | > loss_disc_real_3: 0.24045  (0.25185)
#      | > loss_disc_real_4: 0.25358  (0.25634)
#      | > loss_disc_real_5: 0.26662  (0.28010)
#      | > loss_0: 2.88783  (2.92709)
#      | > grad_norm_0: 5.66561  (16.92798)
#      | > loss_gen: 1.61563  (1.78092)
#      | > loss_kl: 1.57348  (1.67520)
#      | > loss_feat: 0.82507  (0.87036)
#      | > loss_mel: 29.97644  (30.32240)
#      | > loss_duration: 1.85573  (1.80577)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 35.84634  (36.45465)
#      | > grad_norm_1: 146.07886  (233.31717)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 4.04370  (3.85282)
#      | > loader_time: 0.01500  (0.01093)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01802 (+0.00801)
#      | > avg_loss_disc: 2.90947 (+0.02721)
#      | > avg_loss_disc_real_0: 0.13241 (-0.03721)
#      | > avg_loss_disc_real_1: 0.24035 (-0.03865)
#      | > avg_loss_disc_real_2: 0.26150 (+0.03528)
#      | > avg_loss_disc_real_3: 0.22592 (-0.00227)
#      | > avg_loss_disc_real_4: 0.23155 (-0.05201)
#      | > avg_loss_disc_real_5: 0.23095 (-0.03010)
#      | > avg_loss_0: 2.90947 (+0.02721)
#      | > avg_loss_gen: 1.44666 (-0.14926)
#      | > avg_loss_kl: 1.52208 (+0.25121)
#      | > avg_loss_feat: 0.50777 (+0.06454)
#      | > avg_loss_mel: 28.99157 (+1.09352)
#      | > avg_loss_duration: 1.93411 (-0.02475)
#      | > avg_loss_1: 34.40219 (+1.23526)
#
#
#  > EPOCH: 7/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:33:46)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 15/80 -- GLOBAL_STEP: 575
#      | > loss_disc: 2.75306  (2.88276)
#      | > loss_disc_real_0: 0.07507  (0.21105)
#      | > loss_disc_real_1: 0.25930  (0.25302)
#      | > loss_disc_real_2: 0.20594  (0.25044)
#      | > loss_disc_real_3: 0.24383  (0.24900)
#      | > loss_disc_real_4: 0.24383  (0.24538)
#      | > loss_disc_real_5: 0.27076  (0.25453)
#      | > loss_0: 2.75306  (2.88276)
#      | > grad_norm_0: 24.78207  (9.48525)
#      | > loss_gen: 1.88194  (1.70840)
#      | > loss_kl: 1.84662  (1.75102)
#      | > loss_feat: 1.02333  (0.78417)
#      | > loss_mel: 27.80295  (28.93932)
#      | > loss_duration: 1.68762  (1.75477)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 34.24245  (34.93769)
#      | > grad_norm_1: 285.24994  (290.26987)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.77560  (4.13891)
#      | > loader_time: 0.01000  (0.00904)
#
#
#    --> STEP: 40/80 -- GLOBAL_STEP: 600
#      | > loss_disc: 2.84544  (2.85240)
#      | > loss_disc_real_0: 0.28802  (0.21654)
#      | > loss_disc_real_1: 0.27706  (0.24825)
#      | > loss_disc_real_2: 0.26390  (0.24938)
#      | > loss_disc_real_3: 0.26959  (0.24608)
#      | > loss_disc_real_4: 0.26152  (0.24623)
#      | > loss_disc_real_5: 0.27193  (0.24430)
#      | > loss_0: 2.84544  (2.85240)
#      | > grad_norm_0: 19.71279  (14.54964)
#      | > loss_gen: 1.84096  (1.71730)
#      | > loss_kl: 1.53213  (1.72586)
#      | > loss_feat: 0.99784  (0.85782)
#      | > loss_mel: 30.47859  (29.32889)
#      | > loss_duration: 1.84954  (1.77492)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 36.69906  (35.40479)
#      | > grad_norm_1: 211.22247  (253.85266)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.81500  (3.91587)
#      | > loader_time: 0.01000  (0.01136)
#
#
#    --> STEP: 65/80 -- GLOBAL_STEP: 625
#      | > loss_disc: 2.89715  (2.87022)
#      | > loss_disc_real_0: 0.26753  (0.22478)
#      | > loss_disc_real_1: 0.27460  (0.24824)
#      | > loss_disc_real_2: 0.27912  (0.24914)
#      | > loss_disc_real_3: 0.29272  (0.24736)
#      | > loss_disc_real_4: 0.28607  (0.24707)
#      | > loss_disc_real_5: 0.34548  (0.24573)
#      | > loss_0: 2.89715  (2.87022)
#      | > grad_norm_0: 15.31547  (15.68989)
#      | > loss_gen: 1.83497  (1.70189)
#      | > loss_kl: 1.73320  (1.70449)
#      | > loss_feat: 0.83256  (0.81094)
#      | > loss_mel: 29.34995  (29.30435)
#      | > loss_duration: 1.87818  (1.80506)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 35.62886  (35.32673)
#      | > grad_norm_1: 221.15953  (269.91519)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 5.32550  (3.93416)
#      | > loader_time: 0.01400  (0.01172)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01201 (-0.00600)
#      | > avg_loss_disc: 2.89020 (-0.01927)
#      | > avg_loss_disc_real_0: 0.20231 (+0.06989)
#      | > avg_loss_disc_real_1: 0.23714 (-0.00321)
#      | > avg_loss_disc_real_2: 0.15276 (-0.10873)
#      | > avg_loss_disc_real_3: 0.17746 (-0.04846)
#      | > avg_loss_disc_real_4: 0.16875 (-0.06280)
#      | > avg_loss_disc_real_5: 0.13469 (-0.09626)
#      | > avg_loss_0: 2.89020 (-0.01927)
#      | > avg_loss_gen: 1.24186 (-0.20480)
#      | > avg_loss_kl: 1.47913 (-0.04295)
#      | > avg_loss_feat: 0.53594 (+0.02817)
#      | > avg_loss_mel: 25.85097 (-3.14061)
#      | > avg_loss_duration: 1.97993 (+0.04583)
#      | > avg_loss_1: 31.08783 (-3.31437)
#
#  > BEST MODEL : ./output\vits_vctk-September-23-2022_02+46AM-3c624ce\best_model_640.pth
#
#  > EPOCH: 8/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:40:08)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 10/80 -- GLOBAL_STEP: 650
#      | > loss_disc: 2.88375  (2.83719)
#      | > loss_disc_real_0: 0.24939  (0.21920)
#      | > loss_disc_real_1: 0.29363  (0.24729)
#      | > loss_disc_real_2: 0.27808  (0.25801)
#      | > loss_disc_real_3: 0.19382  (0.25378)
#      | > loss_disc_real_4: 0.20492  (0.25203)
#      | > loss_disc_real_5: 0.19402  (0.23157)
#      | > loss_0: 2.88375  (2.83719)
#      | > grad_norm_0: 15.00054  (12.11371)
#      | > loss_gen: 1.68873  (1.71992)
#      | > loss_kl: 1.60884  (1.70320)
#      | > loss_feat: 0.79929  (0.76377)
#      | > loss_mel: 28.56273  (28.57067)
#      | > loss_duration: 1.69726  (1.76856)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 34.35686  (34.52612)
#      | > grad_norm_1: 272.05252  (439.99576)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.73620  (3.70636)
#      | > loader_time: 0.01000  (0.00851)
#
#
#    --> STEP: 35/80 -- GLOBAL_STEP: 675
#      | > loss_disc: 2.64242  (2.87036)
#      | > loss_disc_real_0: 0.18795  (0.23228)
#      | > loss_disc_real_1: 0.22150  (0.24514)
#      | > loss_disc_real_2: 0.23508  (0.24890)
#      | > loss_disc_real_3: 0.27443  (0.24876)
#      | > loss_disc_real_4: 0.24698  (0.24855)
#      | > loss_disc_real_5: 0.23803  (0.24687)
#      | > loss_0: 2.64242  (2.87036)
#      | > grad_norm_0: 14.85988  (14.68128)
#      | > loss_gen: 1.52383  (1.68299)
#      | > loss_kl: 1.82217  (1.66445)
#      | > loss_feat: 1.16121  (0.75763)
#      | > loss_mel: 29.90451  (28.61107)
#      | > loss_duration: 1.84113  (1.76952)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 36.25285  (34.48566)
#      | > grad_norm_1: 218.36104  (349.83221)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.79400  (3.74824)
#      | > loader_time: 0.01100  (0.00952)
#
#
#    --> STEP: 60/80 -- GLOBAL_STEP: 700
#      | > loss_disc: 2.74082  (2.86352)
#      | > loss_disc_real_0: 0.15749  (0.22215)
#      | > loss_disc_real_1: 0.22416  (0.24939)
#      | > loss_disc_real_2: 0.21932  (0.24940)
#      | > loss_disc_real_3: 0.25833  (0.24931)
#      | > loss_disc_real_4: 0.19429  (0.24891)
#      | > loss_disc_real_5: 0.22821  (0.24810)
#      | > loss_0: 2.74082  (2.86352)
#      | > grad_norm_0: 15.66578  (17.13105)
#      | > loss_gen: 1.68226  (1.70779)
#      | > loss_kl: 1.50867  (1.63127)
#      | > loss_feat: 1.12372  (0.84246)
#      | > loss_mel: 28.50002  (28.78029)
#      | > loss_duration: 1.91444  (1.80069)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 34.72911  (34.76250)
#      | > grad_norm_1: 413.71793  (336.25330)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.99130  (3.80038)
#      | > loader_time: 0.01300  (0.01049)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.01001 (-0.00200)
#      | > avg_loss_disc: 2.90152 (+0.01133)
#      | > avg_loss_disc_real_0: 0.20969 (+0.00739)
#      | > avg_loss_disc_real_1: 0.27112 (+0.03398)
#      | > avg_loss_disc_real_2: 0.25838 (+0.10561)
#      | > avg_loss_disc_real_3: 0.29743 (+0.11997)
#      | > avg_loss_disc_real_4: 0.24999 (+0.08124)
#      | > avg_loss_disc_real_5: 0.33683 (+0.20214)
#      | > avg_loss_0: 2.90152 (+0.01133)
#      | > avg_loss_gen: 1.77477 (+0.53291)
#      | > avg_loss_kl: 1.72360 (+0.24447)
#      | > avg_loss_feat: 0.60578 (+0.06984)
#      | > avg_loss_mel: 26.27793 (+0.42696)
#      | > avg_loss_duration: 1.93578 (-0.04415)
#      | > avg_loss_1: 32.31786 (+1.23003)
#
#
#  > EPOCH: 9/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-23 03:46:11)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 5/80 -- GLOBAL_STEP: 725
#      | > loss_disc: 2.83291  (2.86697)
#      | > loss_disc_real_0: 0.17815  (0.23548)
#      | > loss_disc_real_1: 0.22700  (0.23706)
#      | > loss_disc_real_2: 0.27813  (0.24939)
#      | > loss_disc_real_3: 0.25312  (0.23349)
#      | > loss_disc_real_4: 0.21067  (0.23470)
#      | > loss_disc_real_5: 0.23793  (0.21841)
#      | > loss_0: 2.83291  (2.86697)
#      | > grad_norm_0: 21.49244  (19.95113)
#      | > loss_gen: 1.78805  (1.63230)
#      | > loss_kl: 1.49709  (1.62903)
#      | > loss_feat: 0.92652  (0.76766)
#      | > loss_mel: 27.93019  (28.57004)
#      | > loss_duration: 1.82928  (1.79821)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 33.97114  (34.39724)
#      | > grad_norm_1: 274.78519  (305.40323)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
#      | > step_time: 3.72490  (3.67506)
#      | > loader_time: 0.00900  (0.00781)
#
#
#    --> STEP: 30/80 -- GLOBAL_STEP: 750
#      | > loss_disc: 2.97954  (2.84505)
#      | > loss_disc_real_0: 0.11278  (0.21701)
#      | > loss_disc_real_1: 0.18186  (0.24551)
#      | > loss_disc_real_2: 0.20673  (0.24718)
#      | > loss_disc_real_3: 0.25827  (0.24264)
#      | > loss_disc_real_4: 0.28929  (0.24505)
#      | > loss_disc_real_5: 0.29221  (0.23888)
#      | > loss_0: 2.97954  (2.84505)
#      | > grad_norm_0: 38.21983  (20.69103)
#      | > loss_gen: 1.81926  (1.69998)
#      | > loss_kl: 1.65138  (1.61174)
#      | > loss_feat: 0.73834  (0.86148)
#      | > loss_mel: 27.09452  (28.25305)
#      | > loss_duration: 1.82451  (1.76408)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 33.12802  (34.19032)
#      | > grad_norm_1: 276.83072  (373.22375)
#      | > current_lr_0: 0.00020
#      | > current_lr_1: 0.00020
# ...
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 15/80 -- GLOBAL_STEP: 18575
#      | > loss_disc: 2.78870  (2.72439)
#      | > loss_disc_real_0: 0.18974  (0.21277)
#      | > loss_disc_real_1: 0.25278  (0.22316)
#      | > loss_disc_real_2: 0.22439  (0.22826)
#      | > loss_disc_real_3: 0.25110  (0.23407)
#      | > loss_disc_real_4: 0.23936  (0.24071)
#      | > loss_disc_real_5: 0.23484  (0.24662)
#      | > loss_0: 2.78870  (2.72439)
#      | > grad_norm_0: 55.10986  (69.18109)
#      | > loss_gen: 1.99575  (1.93392)
#      | > loss_kl: 1.59911  (1.36126)
#      | > loss_feat: 2.85352  (2.89298)
#      | > loss_mel: 18.40900  (18.52712)
#      | > loss_duration: 1.40483  (1.44820)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.26220  (26.16348)
#      | > grad_norm_1: 484.19925  (602.07788)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.62530  (3.57812)
#      | > loader_time: 0.00900  (0.00874)
#
#
#    --> STEP: 40/80 -- GLOBAL_STEP: 18600
#      | > loss_disc: 2.66896  (2.71980)
#      | > loss_disc_real_0: 0.20184  (0.21017)
#      | > loss_disc_real_1: 0.23961  (0.22500)
#      | > loss_disc_real_2: 0.24067  (0.22498)
#      | > loss_disc_real_3: 0.22942  (0.23703)
#      | > loss_disc_real_4: 0.22323  (0.24110)
#      | > loss_disc_real_5: 0.24416  (0.24687)
#      | > loss_0: 2.66896  (2.71980)
#      | > grad_norm_0: 29.18338  (50.58627)
#      | > loss_gen: 1.72225  (1.92169)
#      | > loss_kl: 1.58066  (1.39979)
#      | > loss_feat: 2.82402  (2.90579)
#      | > loss_mel: 18.45753  (18.59950)
#      | > loss_duration: 1.53639  (1.48633)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.12084  (26.31310)
#      | > grad_norm_1: 608.70758  (465.09439)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.66530  (3.62545)
#      | > loader_time: 0.01300  (0.00956)
#
#
#    --> STEP: 65/80 -- GLOBAL_STEP: 18625
#      | > loss_disc: 2.64179  (2.71863)
#      | > loss_disc_real_0: 0.17021  (0.20601)
#      | > loss_disc_real_1: 0.20814  (0.22552)
#      | > loss_disc_real_2: 0.20672  (0.22730)
#      | > loss_disc_real_3: 0.20791  (0.23594)
#      | > loss_disc_real_4: 0.23606  (0.24130)
#      | > loss_disc_real_5: 0.24145  (0.24662)
#      | > loss_0: 2.64179  (2.71863)
#      | > grad_norm_0: 66.96613  (52.15979)
#      | > loss_gen: 2.09314  (1.92583)
#      | > loss_kl: 1.45893  (1.41078)
#      | > loss_feat: 3.14706  (2.89819)
#      | > loss_mel: 18.98784  (18.53078)
#      | > loss_duration: 1.53879  (1.51879)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 27.22576  (26.28437)
#      | > grad_norm_1: 943.98456  (494.31201)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.85250  (3.68279)
#      | > loader_time: 0.01300  (0.01053)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (+0.00000)
#      | > avg_loss_disc: 2.64393 (-0.04872)
#      | > avg_loss_disc_real_0: 0.18222 (+0.05512)
#      | > avg_loss_disc_real_1: 0.27478 (+0.05993)
#      | > avg_loss_disc_real_2: 0.23552 (-0.03960)
#      | > avg_loss_disc_real_3: 0.27780 (+0.01960)
#      | > avg_loss_disc_real_4: 0.26524 (+0.03031)
#      | > avg_loss_disc_real_5: 0.25489 (-0.00795)
#      | > avg_loss_0: 2.64393 (-0.04872)
#      | > avg_loss_gen: 2.10566 (+0.27504)
#      | > avg_loss_kl: 1.80176 (+0.34517)
#      | > avg_loss_feat: 2.68259 (+0.03258)
#      | > avg_loss_mel: 18.03886 (-0.60657)
#      | > avg_loss_duration: 2.01306 (+0.03271)
#      | > avg_loss_1: 26.64193 (+0.07893)
#
#
#  > EPOCH: 233/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-24 01:02:36)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 10/80 -- GLOBAL_STEP: 18650
#      | > loss_disc: 2.67437  (2.69621)
#      | > loss_disc_real_0: 0.21890  (0.19087)
#      | > loss_disc_real_1: 0.21556  (0.22250)
#      | > loss_disc_real_2: 0.18917  (0.22638)
#      | > loss_disc_real_3: 0.27813  (0.23996)
#      | > loss_disc_real_4: 0.23162  (0.23975)
#      | > loss_disc_real_5: 0.24241  (0.24966)
#      | > loss_0: 2.67437  (2.69621)
#      | > grad_norm_0: 45.30297  (47.00296)
#      | > loss_gen: 1.96418  (1.93877)
#      | > loss_kl: 1.24874  (1.35418)
#      | > loss_feat: 2.92401  (2.97949)
#      | > loss_mel: 18.65106  (18.56644)
#      | > loss_duration: 1.42147  (1.45633)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.20946  (26.29520)
#      | > grad_norm_1: 517.35101  (483.70612)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.60230  (3.56274)
#      | > loader_time: 0.00900  (0.00871)
#
#
#    --> STEP: 35/80 -- GLOBAL_STEP: 18675
#      | > loss_disc: 2.77236  (2.71994)
#      | > loss_disc_real_0: 0.20679  (0.20331)
#      | > loss_disc_real_1: 0.21817  (0.22660)
#      | > loss_disc_real_2: 0.20541  (0.22834)
#      | > loss_disc_real_3: 0.25141  (0.23683)
#      | > loss_disc_real_4: 0.22613  (0.24129)
#      | > loss_disc_real_5: 0.24343  (0.24675)
#      | > loss_0: 2.77236  (2.71994)
#      | > grad_norm_0: 9.02182  (61.23414)
#      | > loss_gen: 2.04435  (1.94379)
#      | > loss_kl: 1.50062  (1.38481)
#      | > loss_feat: 3.14090  (2.92686)
#      | > loss_mel: 19.26797  (18.54547)
#      | > loss_duration: 1.54182  (1.48125)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 27.49566  (26.28218)
#      | > grad_norm_1: 1092.22205  (545.77429)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.67330  (3.61140)
#      | > loader_time: 0.01200  (0.00944)
#
#
#    --> STEP: 60/80 -- GLOBAL_STEP: 18700
#      | > loss_disc: 2.82605  (2.73683)
#      | > loss_disc_real_0: 0.17683  (0.20764)
#      | > loss_disc_real_1: 0.20825  (0.23106)
#      | > loss_disc_real_2: 0.24777  (0.23235)
#      | > loss_disc_real_3: 0.21741  (0.23707)
#      | > loss_disc_real_4: 0.22208  (0.24283)
#      | > loss_disc_real_5: 0.25295  (0.24603)
#      | > loss_0: 2.82605  (2.73683)
#      | > grad_norm_0: 48.67797  (68.88269)
#      | > loss_gen: 1.80549  (1.93895)
#      | > loss_kl: 1.64990  (1.39892)
#      | > loss_feat: 2.81121  (2.90585)
#      | > loss_mel: 19.15274  (18.61492)
#      | > loss_duration: 1.63399  (1.51435)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 27.05334  (26.37300)
#      | > grad_norm_1: 621.86218  (584.19958)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.84550  (3.66655)
#      | > loader_time: 0.01400  (0.01046)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00000)
#      | > avg_loss_disc: 2.65026 (+0.00633)
#      | > avg_loss_disc_real_0: 0.11065 (-0.07158)
#      | > avg_loss_disc_real_1: 0.20804 (-0.06674)
#      | > avg_loss_disc_real_2: 0.25725 (+0.02173)
#      | > avg_loss_disc_real_3: 0.20025 (-0.07755)
#      | > avg_loss_disc_real_4: 0.25074 (-0.01450)
#      | > avg_loss_disc_real_5: 0.25019 (-0.00470)
#      | > avg_loss_0: 2.65026 (+0.00633)
#      | > avg_loss_gen: 1.81285 (-0.29281)
#      | > avg_loss_kl: 1.57697 (-0.22479)
#      | > avg_loss_feat: 3.02818 (+0.34559)
#      | > avg_loss_mel: 18.81209 (+0.77323)
#      | > avg_loss_duration: 2.02575 (+0.01269)
#      | > avg_loss_1: 27.25584 (+0.61390)
#
#
#  > EPOCH: 234/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-24 01:08:11)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 5/80 -- GLOBAL_STEP: 18725
#      | > loss_disc: 2.69117  (2.68112)
#      | > loss_disc_real_0: 0.19809  (0.21334)
#      | > loss_disc_real_1: 0.21381  (0.22162)
#      | > loss_disc_real_2: 0.16317  (0.21700)
#      | > loss_disc_real_3: 0.25766  (0.24384)
#      | > loss_disc_real_4: 0.25317  (0.23998)
#      | > loss_disc_real_5: 0.25501  (0.24867)
#      | > loss_0: 2.69117  (2.68112)
#      | > grad_norm_0: 41.09038  (52.91206)
#      | > loss_gen: 1.87524  (1.92238)
#      | > loss_kl: 1.34350  (1.28926)
#      | > loss_feat: 2.82058  (2.98611)
#      | > loss_mel: 18.10690  (18.42022)
#      | > loss_duration: 1.47239  (1.46035)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 25.61861  (26.07831)
#      | > grad_norm_1: 583.46613  (711.34644)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.57530  (3.54223)
#      | > loader_time: 0.00800  (0.00800)
#
#
#    --> STEP: 30/80 -- GLOBAL_STEP: 18750
#      | > loss_disc: 2.72111  (2.72025)
#      | > loss_disc_real_0: 0.18862  (0.20828)
#      | > loss_disc_real_1: 0.21950  (0.23112)
#      | > loss_disc_real_2: 0.25454  (0.22979)
#      | > loss_disc_real_3: 0.24871  (0.23745)
#      | > loss_disc_real_4: 0.23872  (0.24450)
#      | > loss_disc_real_5: 0.25525  (0.24648)
#      | > loss_0: 2.72111  (2.72025)
#      | > grad_norm_0: 17.70057  (64.72726)
#      | > loss_gen: 1.72587  (1.94961)
#      | > loss_kl: 1.43535  (1.35790)
#      | > loss_feat: 2.57265  (2.96062)
#      | > loss_mel: 18.83471  (18.58840)
#      | > loss_duration: 1.51437  (1.46941)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.08295  (26.32594)
#      | > grad_norm_1: 474.33521  (634.64203)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.66230  (3.60381)
#      | > loader_time: 0.01000  (0.01001)
#
#
#    --> STEP: 55/80 -- GLOBAL_STEP: 18775
#      | > loss_disc: 2.64286  (2.71563)
#      | > loss_disc_real_0: 0.17758  (0.20563)
#      | > loss_disc_real_1: 0.19503  (0.23040)
#      | > loss_disc_real_2: 0.24786  (0.22781)
#      | > loss_disc_real_3: 0.22510  (0.23725)
#      | > loss_disc_real_4: 0.22353  (0.24253)
#      | > loss_disc_real_5: 0.22234  (0.24480)
#      | > loss_0: 2.64286  (2.71563)
#      | > grad_norm_0: 29.76262  (67.64504)
#      | > loss_gen: 1.92613  (1.94086)
#      | > loss_kl: 1.31151  (1.38889)
#      | > loss_feat: 3.27867  (2.92654)
#      | > loss_mel: 18.39375  (18.48228)
#      | > loss_duration: 1.60221  (1.50601)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.51226  (26.24458)
#      | > grad_norm_1: 331.89517  (569.41693)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.78440  (3.65362)
#      | > loader_time: 0.01200  (0.01048)
#
#
#  > EVALUATION
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 25
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 36
#  | > Avg text length: 49.64
#  |
#  | > Max audio length: 146689.0
#  | > Min audio length: 45363.0
#  | > Avg audio length: 68484.4
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 0.
#  | > Synthesizing test sentences.
#   --> EVAL PERFORMANCE
#      | > avg_loader_time: 0.00901 (-0.00000)
#      | > avg_loss_disc: 2.66726 (+0.01700)
#      | > avg_loss_disc_real_0: 0.20332 (+0.09268)
#      | > avg_loss_disc_real_1: 0.22393 (+0.01589)
#      | > avg_loss_disc_real_2: 0.27154 (+0.01429)
#      | > avg_loss_disc_real_3: 0.24568 (+0.04543)
#      | > avg_loss_disc_real_4: 0.26410 (+0.01336)
#      | > avg_loss_disc_real_5: 0.26303 (+0.01284)
#      | > avg_loss_0: 2.66726 (+0.01700)
#      | > avg_loss_gen: 2.00895 (+0.19610)
#      | > avg_loss_kl: 1.65556 (+0.07859)
#      | > avg_loss_feat: 2.61618 (-0.41200)
#      | > avg_loss_mel: 17.88013 (-0.93196)
#      | > avg_loss_duration: 2.00462 (-0.02112)
#      | > avg_loss_1: 26.16546 (-1.09038)
#
#
#  > EPOCH: 235/1000
#  --> ./output\vits_vctk-September-23-2022_02+46AM-3c624ce
# > DataLoader initialization
# | > Tokenizer:
# 	| > add_blank: True
# 	| > use_eos_bos: False
# 	| > use_phonemes: True
# 	| > phonemizer:
# 		| > phoneme language: en
# 		| > phoneme backend: gruut
# 	| > 1 not found characters:
# 	| > ͡
# | > Number of instances : 2555
#  > TRAINING (2022-09-24 01:13:47)
#  | > Preprocessing samples
#  | > Max text length: 81
#  | > Min text length: 16
#  | > Avg text length: 49.37025440313111
#  |
#  | > Max audio length: 171808.0
#  | > Min audio length: 21798.0
#  | > Avg audio length: 67219.45401174168
#  | > Num. instances discarded samples: 0
#  | > Batch group size: 160.
#    --> STEP: 0/80 -- GLOBAL_STEP: 18800
#      | > loss_disc: 2.70787  (2.70787)
#      | > loss_disc_real_0: 0.18303  (0.18303)
#      | > loss_disc_real_1: 0.20511  (0.20511)
#      | > loss_disc_real_2: 0.25571  (0.25571)
#      | > loss_disc_real_3: 0.23978  (0.23978)
#      | > loss_disc_real_4: 0.23067  (0.23067)
#      | > loss_disc_real_5: 0.23985  (0.23985)
#      | > loss_0: 2.70787  (2.70787)
#      | > grad_norm_0: 159.85724  (159.85724)
#      | > loss_gen: 1.83592  (1.83592)
#      | > loss_kl: 1.19972  (1.19972)
#      | > loss_feat: 3.00049  (3.00049)
#      | > loss_mel: 18.62750  (18.62750)
#      | > loss_duration: 1.45286  (1.45286)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.11650  (26.11650)
#      | > grad_norm_1: 910.97003  (910.97003)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.54620  (3.54623)
#      | > loader_time: 23.70830  (23.70827)
#
#
#    --> STEP: 25/80 -- GLOBAL_STEP: 18825
#      | > loss_disc: 2.64383  (2.70995)
#      | > loss_disc_real_0: 0.20514  (0.20101)
#      | > loss_disc_real_1: 0.23408  (0.22402)
#      | > loss_disc_real_2: 0.21143  (0.23123)
#      | > loss_disc_real_3: 0.23240  (0.23583)
#      | > loss_disc_real_4: 0.21548  (0.24193)
#      | > loss_disc_real_5: 0.20642  (0.24454)
#      | > loss_0: 2.64383  (2.70995)
#      | > grad_norm_0: 95.54022  (72.68933)
#      | > loss_gen: 1.84905  (1.93712)
#      | > loss_kl: 1.26523  (1.34505)
#      | > loss_feat: 2.96887  (2.90932)
#      | > loss_mel: 18.45214  (18.38715)
#      | > loss_duration: 1.50684  (1.46419)
#      | > amp_scaler: 128.00000  (128.00000)
#      | > loss_1: 26.04213  (26.04281)
#      | > grad_norm_1: 776.14880  (605.22345)
#      | > current_lr_0: 0.00019
#      | > current_lr_1: 0.00019
#      | > step_time: 3.65430  (3.59651)
#      | > loader_time: 0.01000  (0.00905)

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir="./output\run-September-15-2022_04+45AM-910d77a"
# Out:
#       <iframe id="tensorboard-frame-e1f742ca6b5fa6c3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e1f742ca6b5fa6c3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
